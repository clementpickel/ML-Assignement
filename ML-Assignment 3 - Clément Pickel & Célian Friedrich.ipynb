# %% [markdown]
# # Machine Learning - Assignment 3
#
# ## Artificial Neural Network

# %% [markdown]
# The aim of the assignment is to implement an artificial neural network (mostly) from scratch. This includes implementing or fixing the following:
#
# * Add support for additional activation functions and their derivatives.
# * Add support for loss functions and their derivative.
# * Add the use of a bias in the forward propagation.
# * Add the use of a bias in the backward propagation.
#
# In addition, you will we doing the following as well:
#
# * Test the algorithm on 3 datasets.
# * Compare neural networks with and without scaling.
# * Hyper-parameter tuning.
#
# The forward and backward propagation is made to work through a single layer, and are re-used multiple times to work for multiple layers.
#
# Follow the instructions and implement what is missing to complete the assignment. Some functions have been started to help you a little bit with the implementation.
#
# **Note:** You might need to go back and forth during your implementation of the code. The structure is set up to make implementation easier, you might find yourself going back and and forth to change something to make it easier later on.

# %% [markdown]
# ## Assignment preparations

# %% [markdown]
# We help you out with importing the libraries.
#
# **IMPORTANT NOTE:** You may not import any more libraries than the ones already imported!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# We set seed to better reproduce results later on.
np.random.seed(12345)

# %% [markdown]
# ## Neural Network utility functions

# %% [markdown]
# ### 1) Activation functions
#
# Below is some setup for choosing activation function. Implement 2 additional activation functions, "ReLU" and one more of your choosing.

# %%
# Activation functions
def activate(activations, selected_function = "none"):
    if selected_function == "none":
        y = activations
    elif selected_function == "relu" :
        # TODO: Implement the "ReLU" activation function
        y = np.maximum(0, activations)
    elif selected_function == "sigmoid" :
        # TODO: Implement another activation function activation function of your own choice.
        y = 1 / (1 + np.exp(-activations))
    elif selected_function == "softmax":
        exp_vals = np.exp(activations - np.max(activations, axis=0, keepdims=True))
        y = exp_vals / np.sum(exp_vals, axis=0, keepdims=True)
    return y

# %%
# TODO Test your activation functions, is the returning values what you expect?
test_values = np.array([-2, -1, 0, 1, 2, 3, 5])
print("Activation 'none' :", activate(test_values, "none"))
print("Activation 'relu' :", activate(test_values, "relu"))
print("Activation 'sigmoid' :", activate(test_values, "sigmoid"))
print("Activation 'softmax' :", activate(test_values, "softmax"))
# Out:
# Activation 'none' : [-2 -1  0  1  2  3  5]
# Activation 'relu' : [0 0 0 1 2 3 5]
# Activation 'sigmoid' : [0.11920292 0.26894142 0.5        0.73105858 0.88079708 0.95257413
#  0.99330715]
# Activation 'softmax' : [7.51406628e-04 2.04253498e-03 5.55218573e-03 1.50924056e-02
#  4.10254118e-02 1.11518631e-01 8.24017424e-01]

# %% [markdown]
# ### 2) Activation function derivatives
#
# Neural networks need both the activation function and its derivative. Finish the code below.

# %%
def d_activate(activations, selected_function = "none"):
    if selected_function == "none":
        dy = np.ones_like(activations)
    elif selected_function == "relu":
        # TODO: Implement the "ReLU" derivative
        dy = np.where(activations > 0, 1, 0)
    elif selected_function == "sigmoid" :
        # TODO: Implement the derivative of the activation function you chose yourself.
        sigmoid = 1 / (1 + np.exp(-activations))
        dy = sigmoid * (1 - sigmoid)
    elif selected_function == "softmax":
        dy = np.ones_like(activations)
    return dy

# %%
# TODO Test your activation function derivatives, is the returning values what you expect?
test_values = np.array([-2, -1, 0, 1, 2, 3, 5])
print("Derivative 'none' :", d_activate(test_values, "none"))
print("Derivative 'relu' :", d_activate(test_values, "relu"))
print("Derivative 'sigmoid' :", d_activate(test_values, "sigmoid"))
print("Derivative 'softmax' :", d_activate(test_values, "softmax"))
# Out:
# Derivative 'none' : [1 1 1 1 1 1 1]
# Derivative 'relu' : [0 0 0 1 1 1 1]
# Derivative 'sigmoid' : [0.10499359 0.19661193 0.25       0.19661193 0.10499359 0.04517666
#  0.00664806]
# Derivative 'softmax' : [1 1 1 1 1 1 1]

# %% [markdown]
# ### 3) Loss functions
#
# To penalize the network when it predicts incorrect, we need to meassure how "bad" the prediction is. This is done with loss-functions.
#
# Similar as with the activation functions, the loss function needs its derivative as well.
#
# Finish the MSE_loss (Mean Squared Error loss), as well as adding one additional loss function.

# %%
# This is the loss for a set of predictions y_hat compared to a set of real valyes y
def MSE_loss(y_hat, y):
    loss = np.mean((y_hat - y) ** 2) # TODO: Finish this function
    return loss


# TODO: Choose another loss function and implement it
def BCE_loss(y_hat, y):
    epsilon = 1e-15
    y_hat = np.clip(y_hat, epsilon, 1 - epsilon)
    loss = -np.mean(y * np.log(y_hat) + (1 - y) * np.log(1 - y_hat)) # TODO: Finish this function
    return loss


def CCE_loss(y_hat, y):
    epsilon = 1e-15
    y_hat = np.clip(y_hat, epsilon, 1 - epsilon)
    loss = -np.mean(np.sum(y * np.log(y_hat), axis=1))
    return loss

# %% [markdown]
# The derivatives of the loss is with respect to the predicted value **y_hat**.

# %%
def d_MSE_loss(y_hat, y):
    dy = 2 * (y_hat - y) / y.size 
    # TODO: Finish this function
    return dy

# TODO: Choose another loss function and implement it
def d_BCE_loss(y_hat, y):
    epsilon = 1e-15
    y_hat = np.clip(y_hat, epsilon, 1 - epsilon)
    dy = (y_hat - y) / (y_hat * (1 - y_hat) * y.size)
    # TODO: Finish this function
    return dy


def d_CCE_loss(y_hat, y):
    dy = (y_hat - y) / y.shape[0]
    return dy

# %% [markdown]
# ### 4) Forward propagation
#
# The first "fundamental" function for neural networks is to be able to propagate the data forward through the neural network. We will implement this function here.

# %%
def propagate_forward(weights, activations, bias, activation_function="none"):
    
    # TODO: Add support for the use of bias

    dot_product = np.dot(weights, activations) + bias

    new_activations = activate(dot_product, activation_function)
    # print("> new_activations", new_activations)

    return new_activations

# %% [markdown]
# ### 5) Back-propagation
#
# To be able to train a neural network, we need to be able to propagate the loss backwards and update the weights. We will implement this function here.

# %%
# Calculates the backward gradients that are passed throught the layer in the backward pass.
# Returns both the derivative of the loss in respect to the weights and the input signal (activations).

def propagate_backward(weights, activations, dl_dz, bias, activation_function="none"):
    # NOTE: dl_dz is the derivative of the loss based on the previous layers activations/outputs

    # TODO: Add support for the use of bias

    z = np.dot(weights, activations) + bias
    d_loss = d_activate(z, activation_function) * dl_dz

    d_weights = np.dot(d_loss, activations.T)
    
    d_bias = np.sum(d_loss, axis=1, keepdims=True)
    d_activations = np.dot(weights.T, d_loss)
    
    return d_weights, d_activations, d_bias

# %% [markdown]
# ## Neural network implementation
#
# ### 6) Fixing the neural network
#
# Below is a class implementation of a MLP neural network. This implementation is still lacking several areas that are needed for the network to be robust and function well. Your task is to improve and fix it with the following:
#
# 1. Add a bias to the activation functions, and make sure the bias is also updated during training.
# 2. Add a function that trains the network using minibatches (such that the neural network trains on a few samples at a time).
# 3. Make use of an validation set in the training function. The model should stop training when the loss starts to increase for the validatin set. This feature should be able to be turned on and off to test the difference.

# %%
def binary_accuracy(y_pred, y_true):
    y_pred_binary = (y_pred >= 0.5).astype(int)
    accuracy = np.mean(y_pred_binary == y_true)
    return accuracy

def categorical_accuracy(y_pred, y_true):
    pred_class = np.argmax(y_pred, axis=1)
    true_class = np.argmax(y_true, axis=1)
    return np.mean(pred_class == true_class)

def r2_score(y_pred, y_true):
    ss_total = np.sum((y_true - np.mean(y_true)) ** 2)
    ss_residual = np.sum((y_true - y_pred) ** 2)
    return 1 - (ss_residual / ss_total)

# %%
class NeuralNet(object):
    
    # Setup all parameters and activation functions.
    # This function runs directly when a new instance of this class is created.
    def __init__ (self, input_dim, output_dim, neurons = [], activation_functions=None, loss_function=MSE_loss, d_loss_function=d_MSE_loss):

        # NOTE: The "neurons" parameter is given as a list.
        # E.g., [4, 8, 4] means 4 neurons in layer 1, 8 neurons in layer 2 etc...

        # TODO: Add support for bias for each neuron in the code below.
        
        self.weights = [np.random.normal(0, 2, (m, n)) for n, m in zip([input_dim] + neurons, neurons + [output_dim])]
        # self.weights = [np.random.normal(0, 0.01, (m, n)) for n, m in zip([input_dim] + neurons, neurons + [output_dim])]
        # self.weights = [np.random.normal(0, np.sqrt(2 / (n_in + n_out)), (n_out, n_in)) for n_in, n_out in zip([input_dim] + neurons, neurons + [output_dim])]


        self.biases = [np.zeros((layer_size, 1)) for layer_size in neurons + [output_dim]]
        
        if activation_functions is None:
            self.activation_functions = ["relu"] * len(neurons) + ["none"]
        else:
            self.activation_functions = activation_functions
        
        self.loss_function = loss_function
        self.d_loss_function = d_loss_function

    # Predict the input throught the network and calculate the output.
    def forward(self, x):
        activation = x.T
        # TODO: Add support for a bias for each neuron in the code below.
        for layer_weights, layer_bias, layer_activation_function in zip(self.weights,self.biases , self.activation_functions):
            activation = propagate_forward(layer_weights, activation, layer_bias, layer_activation_function)
            
        return activation.T
    
    
    # Adjust the weights in the network to better fit the desired output (y), given the input (x).
    # The weight updates are happening "in-place", thus we are only returning the loss from this function.
    # Note that this function can handle a variable size of the input (x), both full datasets or smaller parts of the dataset.
    def adjust_weights(self, x, y, learning_rate=1e-4):
                
        # TODO: Add support for a bias for each neuron and make sure these are learnt as well in the code below.

        activation = x.T
        activation_history = [activation] # NOTE: We need the previous (or intermediate) activations to make use of the "chain rule" (see lecture notes).
        
        for layer_weights, layer_bias, layer_activation_function in zip(self.weights, self.biases, self.activation_functions):

            activation = propagate_forward(layer_weights, activation, layer_bias, layer_activation_function)
            activation_history.append(activation)

        # NOTE: The "activation" variable is changing as we go forward in the neural network.
        y_pred = activation_history[-1].T
        loss = self.loss_function(y_pred, y)
        d_activations = self.d_loss_function(y_pred, y).T# NOTE: The final output can be "seen as" the final activations, thus the name.
        
        for i in range(len(self.weights))[::-1]:
            current_activation = activation_history[i]
            current_wights = self.weights[i]
            current_bias = self.biases[i]
            current_activation_function = self.activation_functions[i]

            d_weights, d_activations, d_bias = propagate_backward(current_wights, current_activation, d_activations, current_bias, current_activation_function)
            
            self.weights[i] -= learning_rate * d_weights
            self.biases[i] -= learning_rate * d_bias
        return loss
    
    
    # A function for the training of the network.
    def train_net(self, x, y, batch_size=32, epochs=100, learning_rate=1e-4, accuracy_function=None):
        
        # TODO: Add a training loop where the weights and biases of the network is learnt over several epochs.

        # TODO: Add support for mini batches. That is, in each epoch the data should be split into several
        #       smaller subsets and the model should be trained on each of these subsets one at a time.

        # TODO: Implement the use of validation data, that is, splitting the training data into training data and validation data.
        #       The validation data should be used to stop the training when the model stops to generalise and starts to overfit.
        #       This feature should be able to be turned on and off to test the difference.

        # NOTE: Make use of previously implemented functions here.
        x_train, y_train = x, y
        history = []
        accuracy_history = []

        for _ in range(epochs):
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]
            
            epoch_loss = 0
            for i in range(0, x_train_shuffled.shape[0], batch_size):
                x_batch = x_train_shuffled[i:i+batch_size]
                y_batch = y_train_shuffled[i:i+batch_size]
                loss = self.adjust_weights(x_batch, y_batch, learning_rate)
                epoch_loss += loss * x_batch.shape[0]
            epoch_loss /= x_train_shuffled.shape[0]
            history.append(epoch_loss)
            
            if accuracy_function is not None:
                y_pred = self.forward(x_train)
                epoch_accuracy = accuracy_function(y_pred, y_train)
                accuracy_history.append(epoch_accuracy)
        return history, accuracy_history

# %% [markdown]
# ## Train Neural Networks

# %% [markdown]
# ### 7) Simple test
#
# In this a very simple test for you to use and toy around with before using the datasets.
#
# Make sure to test both the **adjust_weights** function and the **train_net** function. What is the difference between the two?
#
# Also, be sure to **plot the loss for each epoch** to see how the network training is progressing!

# %%
# TODO: You can change most things in this cell if you want to, we encurage it!

n = 1000
d = 4

k = np.random.randint(0, 10, (d, 1))
x = np.random.normal(0, 1, (n, d))
y = np.dot(x, k) + 0.1 + np.random.normal(0, 0.01, (n, 1))

nn = NeuralNet(d, 1, [18, 12])

loss_1 = [nn.adjust_weights(x, y) for _ in range(1000)]

nn2 = NeuralNet(d, 1, [18, 12])
# TODO: Use the train_net function to compare with the "adjust_weights" function.
loss_2, _ = nn2.train_net(x, y, batch_size=32, epochs=100, learning_rate=1e-4)

plt.figure(figsize=(10, 5))
plt.plot(loss_1)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.title("Loss 1 (adjust_weights)")
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(loss_2)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss 2 (train_net)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Real test and preprocessing
#
# When using real data and neural networks, it is very important to scale the data between smaller values, usually between 0 and 1. This is because neural networks struggle with larger values as input compared to smaller values.
#
# To test this, we will use our first dataset and test with and without scaling.
#
# Similar as with assignment 2, we will use the scikit-learn library for this preprocessing: https://scikit-learn.org/stable/modules/preprocessing.html

# %%
def train_test_split(*arrays, test_size=0.25):
    n_samples = arrays[0].shape[0]
    
    indices = np.arange(n_samples)
    np.random.shuffle(indices)
    
    test_count = int(n_samples * test_size)
    test_indices = indices[:test_count]
    train_indices = indices[test_count:]

    splitted = []
    for arr in arrays:
        train_arr = arr[train_indices]
        test_arr = arr[test_indices]
        splitted.extend([train_arr, test_arr])
    
    return tuple(splitted)

def one_hot_encode(y, num_classes):
    y_onehot = np.zeros((y.shape[0], num_classes))
    for i in range(y.shape[0]):
        # Assuming classes are 1-indexed (1,2,3)
        y_onehot[i, int(y[i])-1] = 1
    return y_onehot

# %% [markdown]
# ### 8) Dataset 1: Wine - with and without scaling
#
# Wine dataset: https://archive.ics.uci.edu/dataset/109/wine
#
# Train two neural network, one with scaling and one without. Are we able to see any difference in training results or loss over time?
#
# **Note:** Do not train for to many epochs (more than maybe 50-100). The network might "learn" anyway in the end, but you should still be able to see a difference when training.

# %%
from sklearn import preprocessing

data_wine = pd.read_csv("wine.csv")
# Read the wine dataset.

data_wine = data_wine.apply(pd.to_numeric, errors='coerce')
data_wine = data_wine.dropna()

# Separate features and labels.
x = data_wine.iloc[:, :-1].to_numpy()
y = data_wine.iloc[:, -1].to_numpy().reshape(-1, 1)

# Convert class labels to one-hot encoding.
num_classes = 3
y_onehot = one_hot_encode(y, num_classes)

indices = np.random.permutation(x.shape[0])
train_size = int(0.8 * x.shape[0])
train_indices = indices[:train_size]
test_indices = indices[train_size:]

x_train = x[train_indices]
x_test = x[test_indices]
y_train = y_onehot[train_indices]
y_test = y_onehot[test_indices]

scaler = preprocessing.StandardScaler()
x_scaled = scaler.fit_transform(x)
x_train_scaled = x_scaled[train_indices]
x_test_scaled = x_scaled[test_indices]

input_dim = x.shape[1]
output_dim = num_classes
neurons = [16, 16]
activation_functions = ["relu", "relu", "softmax"]

epochs = 100
batch_size = 32
learning_rate = 1e-3
runs = 3

loss_histories_raw = []
acc_histories_raw = []

loss_histories_scaled = []
acc_histories_scaled = []
test_accuracies_scaled = []

for run in range(runs):
    net = NeuralNet(input_dim, output_dim, neurons, activation_functions,
                    loss_function=CCE_loss, d_loss_function=d_CCE_loss)
    history, acc_history = net.train_net(x_train, y_train, batch_size=batch_size, epochs=epochs,
                                         learning_rate=learning_rate, accuracy_function=categorical_accuracy)
    loss_histories_raw.append(history)
    acc_histories_raw.append(acc_history)

for run in range(runs):
    net = NeuralNet(input_dim, output_dim, neurons, activation_functions,
                    loss_function=CCE_loss, d_loss_function=d_CCE_loss)
    history, acc_history = net.train_net(x_train_scaled, y_train, batch_size=batch_size, epochs=epochs,
                                         learning_rate=learning_rate, accuracy_function=categorical_accuracy)
    loss_histories_scaled.append(history)
    acc_histories_scaled.append(acc_history)



epochs_range = range(1, epochs+1)

plt.figure(figsize=(12, 6))
# Loss comparison plot
for run in range(runs):
    plt.plot(epochs_range, loss_histories_raw[run], label=f"Raw Run {run+1}")
    plt.plot(epochs_range, loss_histories_scaled[run], linestyle="--", label=f"Scaled Run {run+1}")
plt.title("Training Loss Comparison")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Accuracy comparison plot
plt.figure(figsize=(12, 6))
for run in range(runs):
    plt.plot(epochs_range, acc_histories_raw[run], label=f"Raw Run {run+1}")
    plt.plot(epochs_range, acc_histories_scaled[run], linestyle="--", label=f"Scaled Run {run+1}")
plt.title("Training Accuracy Comparison")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.show()
# Out:
# C:\Users\cpick\AppData\Local\Temp\ipykernel_135640\3714137999.py:23: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_onehot[i, int(y[i])-1] = 1

# %% [markdown]
# ### Real data and hyper-parameter tuning
#
# Now we are going to use real data, preprocess it, and do hyper-parameter tuning.
#
# Choose two hyper-parameters to tune to try and achive an even better result.
#
# **NOTE:** Changing the number of epochs should be part of the tuning, but it does not count towards the two hyper parameters.

# %% [markdown]
# ### 9) Dataset 2: Mushroom
#
# Mushroom dataset: https://archive.ics.uci.edu/dataset/73/mushroom
#
# Note: This dataset has one feature with missing values. Remove this feature.

# %%
data_mushroom = pd.read_csv("mushroom.csv")


# TODO: Preprocess the data.
data_mushroom = data_mushroom[data_mushroom != "?"].dropna()

data_mushroom['edible'] = data_mushroom['edible'].map({'e': 1, 'p': 0})

data_mushroom_encoded = pd.get_dummies(data_mushroom, drop_first=True)

x = data_mushroom_encoded.drop(columns=["edible"]).to_numpy()
y = data_mushroom_encoded["edible"].to_numpy().reshape(-1, 1)

# TODO: Split the data into train and test
indices = np.random.permutation(x.shape[0])

train_size = int(0.8 * x.shape[0])
train_indices = indices[:train_size]
test_indices = indices[train_size:]

x_train, x_test = x[train_indices], x[test_indices]
y_train, y_test = y[train_indices], y[test_indices]

scaler = preprocessing.MinMaxScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)


# TODO: Train a neural network on the data
nn = NeuralNet(input_dim=x_train_scaled.shape[1], output_dim=1, neurons=[32, 16], activation_functions=["relu", "relu", "sigmoid"], loss_function=BCE_loss, d_loss_function=d_BCE_loss)

loss_history, accuracy_history = nn.train_net(x_train_scaled, y_train, batch_size=32, epochs=50, learning_rate=1e-4, accuracy_function=binary_accuracy)

# TODO: Visualize the loss for each epoch
plt.figure(figsize=(12, 6))
plt.plot(loss_history, label="Training Loss", color='blue')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss per Epoch")
plt.legend()
plt.grid(True)
plt.show()

# TODO: Visulaize the test accuracy for each epoch
plt.figure(figsize=(12, 6))
plt.plot(accuracy_history, label="Training Accuracy", color='green')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training Accuracy per Epoch")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50 - Loss: 0.6930 - Accuracy: 0.6204
# Epoch 2/50 - Loss: 0.6928 - Accuracy: 0.6204
# Epoch 3/50 - Loss: 0.6926 - Accuracy: 0.6204
# Epoch 4/50 - Loss: 0.6924 - Accuracy: 0.6204
# Epoch 5/50 - Loss: 0.6922 - Accuracy: 0.6204
# Epoch 6/50 - Loss: 0.6920 - Accuracy: 0.6204
# Epoch 7/50 - Loss: 0.6918 - Accuracy: 0.6204
# Epoch 8/50 - Loss: 0.6916 - Accuracy: 0.6204
# Epoch 9/50 - Loss: 0.6915 - Accuracy: 0.6204
# Epoch 10/50 - Loss: 0.6913 - Accuracy: 0.6204
# Epoch 11/50 - Loss: 0.6911 - Accuracy: 0.6204
# Epoch 12/50 - Loss: 0.6909 - Accuracy: 0.6204
# Epoch 13/50 - Loss: 0.6907 - Accuracy: 0.6204
# Epoch 14/50 - Loss: 0.6905 - Accuracy: 0.6204
# Epoch 15/50 - Loss: 0.6903 - Accuracy: 0.6204
# Epoch 16/50 - Loss: 0.6901 - Accuracy: 0.6204
# Epoch 17/50 - Loss: 0.6900 - Accuracy: 0.6204
# Epoch 18/50 - Loss: 0.6898 - Accuracy: 0.6204
# Epoch 19/50 - Loss: 0.6896 - Accuracy: 0.6204
# Epoch 20/50 - Loss: 0.6894 - Accuracy: 0.6204
# Epoch 21/50 - Loss: 0.6892 - Accuracy: 0.6204
# Epoch 22/50 - Loss: 0.6891 - Accuracy: 0.6204
# Epoch 23/50 - Loss: 0.6889 - Accuracy: 0.6204
# Epoch 24/50 - Loss: 0.6887 - Accuracy: 0.6204
# Epoch 25/50 - Loss: 0.6885 - Accuracy: 0.6204
# Epoch 26/50 - Loss: 0.6884 - Accuracy: 0.6204
# Epoch 27/50 - Loss: 0.6882 - Accuracy: 0.6204
# Epoch 28/50 - Loss: 0.6880 - Accuracy: 0.6204
# Epoch 29/50 - Loss: 0.6879 - Accuracy: 0.6204
# Epoch 30/50 - Loss: 0.6877 - Accuracy: 0.6204
# Epoch 31/50 - Loss: 0.6875 - Accuracy: 0.6204
# Epoch 32/50 - Loss: 0.6873 - Accuracy: 0.6204
# Epoch 33/50 - Loss: 0.6872 - Accuracy: 0.6204
# Epoch 34/50 - Loss: 0.6870 - Accuracy: 0.6204
# Epoch 35/50 - Loss: 0.6869 - Accuracy: 0.6204
# Epoch 36/50 - Loss: 0.6867 - Accuracy: 0.6204
# Epoch 37/50 - Loss: 0.6865 - Accuracy: 0.6204
# Epoch 38/50 - Loss: 0.6864 - Accuracy: 0.6204
# Epoch 39/50 - Loss: 0.6862 - Accuracy: 0.6204
# Epoch 40/50 - Loss: 0.6861 - Accuracy: 0.6204
# Epoch 41/50 - Loss: 0.6859 - Accuracy: 0.6204
# Epoch 42/50 - Loss: 0.6858 - Accuracy: 0.6204
# Epoch 43/50 - Loss: 0.6856 - Accuracy: 0.6204
# Epoch 44/50 - Loss: 0.6855 - Accuracy: 0.6204
# Epoch 45/50 - Loss: 0.6853 - Accuracy: 0.6204
# Epoch 46/50 - Loss: 0.6852 - Accuracy: 0.6204
# Epoch 47/50 - Loss: 0.6850 - Accuracy: 0.6204
# Epoch 48/50 - Loss: 0.6849 - Accuracy: 0.6204
# Epoch 49/50 - Loss: 0.6847 - Accuracy: 0.6204
# Epoch 50/50 - Loss: 0.6846 - Accuracy: 0.6204

# %% [markdown]
# When hyper-parameter tuning, please write the parameters and network sizes you test here:
#
# * Parameter 1:
# * Parameter 2:
#
# * Neural network sizes:

# %%
# TODO: Hyper-parameter tuning
learning_rates = [ 0.001, 0.0001]
batch_size = [32, 64]
network_sizes = [[32, 16], [64, 32]]

best_loss = float('inf')
best_model = None
best_params = None

results = {}

for lr in learning_rates:
    for size in network_sizes:
        for bs in batch_size:
            print(f"Testing network size {size} with learning rate {lr}")
            
            nn = NeuralNet(input_dim=x_train_scaled.shape[1], output_dim=1, neurons=size, activation_functions=["relu"] * len(size) + ["sigmoid"], loss_function=BCE_loss, d_loss_function=d_BCE_loss)
            
            loss_history, accuracy_history = nn.train_net(x_train_scaled, y_train, batch_size=bs, epochs=50, learning_rate=lr, accuracy_function=binary_accuracy)
            
            final_loss = loss_history[-1]
            
            results[(tuple(size), lr, bs)] = (loss_history, accuracy_history)
            
            if final_loss < best_loss:
                best_loss = final_loss
                best_model = nn
                best_params = (size, lr)

print("Best model found with size", best_params[0], "and learning rate", best_params[1])
        

# TODO: Visualize the loss after hyper-parameter tuning for each epoch
plt.figure(figsize=(12, 6))
for key, (loss_history, _) in results.items():
    plt.plot(loss_history, label=f"Size: {key[0]}, LR: {key[1]}, BS: {key[2]}")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss per Epoch (Hyper-parameter Tuning)")
plt.legend()
plt.grid(True)
plt.show()

# TODO: Visulaize the test accuracy after hyper-parameter tuning for each epoch
plt.figure(figsize=(12, 6))
for key, (_, accuracy_history) in results.items():
    plt.plot(accuracy_history, label=f"Size: {key[0]}, LR: {key[1]}, BS: {key[2]}")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Test Accuracy per Epoch (Hyper-parameter Tuning)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Testing network size [32, 16] with learning rate 0.001
# Epoch 1/50 - Loss: 0.6922 - Accuracy: 0.6204
# Epoch 2/50 - Loss: 0.6902 - Accuracy: 0.6204
# Epoch 3/50 - Loss: 0.6884 - Accuracy: 0.6204
# Epoch 4/50 - Loss: 0.6867 - Accuracy: 0.6204
# Epoch 5/50 - Loss: 0.6852 - Accuracy: 0.6204
# Epoch 6/50 - Loss: 0.6837 - Accuracy: 0.6204
# Epoch 7/50 - Loss: 0.6824 - Accuracy: 0.6204
# Epoch 8/50 - Loss: 0.6812 - Accuracy: 0.6204
# Epoch 9/50 - Loss: 0.6800 - Accuracy: 0.6204
# Epoch 10/50 - Loss: 0.6789 - Accuracy: 0.6204
# Epoch 11/50 - Loss: 0.6779 - Accuracy: 0.6204
# Epoch 12/50 - Loss: 0.6769 - Accuracy: 0.6204
# Epoch 13/50 - Loss: 0.6761 - Accuracy: 0.6204
# Epoch 14/50 - Loss: 0.6753 - Accuracy: 0.6204
# Epoch 15/50 - Loss: 0.6745 - Accuracy: 0.6204
# Epoch 16/50 - Loss: 0.6738 - Accuracy: 0.6204
# Epoch 17/50 - Loss: 0.6731 - Accuracy: 0.6204
# Epoch 18/50 - Loss: 0.6725 - Accuracy: 0.6204
# Epoch 19/50 - Loss: 0.6719 - Accuracy: 0.6204
# Epoch 20/50 - Loss: 0.6714 - Accuracy: 0.6204
# Epoch 21/50 - Loss: 0.6709 - Accuracy: 0.6204
# Epoch 22/50 - Loss: 0.6704 - Accuracy: 0.6204
# Epoch 23/50 - Loss: 0.6700 - Accuracy: 0.6204
# Epoch 24/50 - Loss: 0.6695 - Accuracy: 0.6204
# Epoch 25/50 - Loss: 0.6692 - Accuracy: 0.6204
# Epoch 26/50 - Loss: 0.6688 - Accuracy: 0.6204
# Epoch 27/50 - Loss: 0.6685 - Accuracy: 0.6204
# Epoch 28/50 - Loss: 0.6682 - Accuracy: 0.6204
# Epoch 29/50 - Loss: 0.6679 - Accuracy: 0.6204
# Epoch 30/50 - Loss: 0.6676 - Accuracy: 0.6204
# Epoch 31/50 - Loss: 0.6674 - Accuracy: 0.6204
# Epoch 32/50 - Loss: 0.6672 - Accuracy: 0.6204
# Epoch 33/50 - Loss: 0.6670 - Accuracy: 0.6204
# Epoch 34/50 - Loss: 0.6667 - Accuracy: 0.6204
# Epoch 35/50 - Loss: 0.6666 - Accuracy: 0.6204
# Epoch 36/50 - Loss: 0.6664 - Accuracy: 0.6204
# Epoch 37/50 - Loss: 0.6662 - Accuracy: 0.6204
# Epoch 38/50 - Loss: 0.6661 - Accuracy: 0.6204
# Epoch 39/50 - Loss: 0.6659 - Accuracy: 0.6204
# Epoch 40/50 - Loss: 0.6658 - Accuracy: 0.6204
# Epoch 41/50 - Loss: 0.6657 - Accuracy: 0.6204
# Epoch 42/50 - Loss: 0.6655 - Accuracy: 0.6204
# Epoch 43/50 - Loss: 0.6654 - Accuracy: 0.6204
# Epoch 44/50 - Loss: 0.6653 - Accuracy: 0.6204
# Epoch 45/50 - Loss: 0.6652 - Accuracy: 0.6204
# Epoch 46/50 - Loss: 0.6651 - Accuracy: 0.6204
# Epoch 47/50 - Loss: 0.6650 - Accuracy: 0.6204
# Epoch 48/50 - Loss: 0.6650 - Accuracy: 0.6204
# Epoch 49/50 - Loss: 0.6649 - Accuracy: 0.6204
# Epoch 50/50 - Loss: 0.6648 - Accuracy: 0.6204
# Testing network size [32, 16] with learning rate 0.001
# Epoch 1/50 - Loss: 0.6926 - Accuracy: 0.6204
# Epoch 2/50 - Loss: 0.6916 - Accuracy: 0.6204
# Epoch 3/50 - Loss: 0.6907 - Accuracy: 0.6204
# Epoch 4/50 - Loss: 0.6898 - Accuracy: 0.6204
# Epoch 5/50 - Loss: 0.6889 - Accuracy: 0.6204
# Epoch 6/50 - Loss: 0.6880 - Accuracy: 0.6204
# Epoch 7/50 - Loss: 0.6872 - Accuracy: 0.6204
# Epoch 8/50 - Loss: 0.6864 - Accuracy: 0.6204
# Epoch 9/50 - Loss: 0.6856 - Accuracy: 0.6204
# Epoch 10/50 - Loss: 0.6848 - Accuracy: 0.6204
# Epoch 11/50 - Loss: 0.6841 - Accuracy: 0.6204
# Epoch 12/50 - Loss: 0.6834 - Accuracy: 0.6204
# Epoch 13/50 - Loss: 0.6828 - Accuracy: 0.6204
# Epoch 14/50 - Loss: 0.6821 - Accuracy: 0.6204
# Epoch 15/50 - Loss: 0.6815 - Accuracy: 0.6204
# Epoch 16/50 - Loss: 0.6809 - Accuracy: 0.6204
# Epoch 17/50 - Loss: 0.6803 - Accuracy: 0.6204
# Epoch 18/50 - Loss: 0.6797 - Accuracy: 0.6204
# Epoch 19/50 - Loss: 0.6792 - Accuracy: 0.6204
# Epoch 20/50 - Loss: 0.6787 - Accuracy: 0.6204
# Epoch 21/50 - Loss: 0.6781 - Accuracy: 0.6204
# Epoch 22/50 - Loss: 0.6777 - Accuracy: 0.6204
# Epoch 23/50 - Loss: 0.6772 - Accuracy: 0.6204
# Epoch 24/50 - Loss: 0.6767 - Accuracy: 0.6204
# Epoch 25/50 - Loss: 0.6763 - Accuracy: 0.6204
# Epoch 26/50 - Loss: 0.6759 - Accuracy: 0.6204
# Epoch 27/50 - Loss: 0.6754 - Accuracy: 0.6204
# Epoch 28/50 - Loss: 0.6750 - Accuracy: 0.6204
# Epoch 29/50 - Loss: 0.6747 - Accuracy: 0.6204
# Epoch 30/50 - Loss: 0.6743 - Accuracy: 0.6204
# Epoch 31/50 - Loss: 0.6739 - Accuracy: 0.6204
# Epoch 32/50 - Loss: 0.6736 - Accuracy: 0.6204
# Epoch 33/50 - Loss: 0.6733 - Accuracy: 0.6204
# Epoch 34/50 - Loss: 0.6729 - Accuracy: 0.6204
# Epoch 35/50 - Loss: 0.6726 - Accuracy: 0.6204
# Epoch 36/50 - Loss: 0.6723 - Accuracy: 0.6204
# Epoch 37/50 - Loss: 0.6721 - Accuracy: 0.6204
# Epoch 38/50 - Loss: 0.6718 - Accuracy: 0.6204
# Epoch 39/50 - Loss: 0.6715 - Accuracy: 0.6204
# Epoch 40/50 - Loss: 0.6712 - Accuracy: 0.6204
# Epoch 41/50 - Loss: 0.6710 - Accuracy: 0.6204
# Epoch 42/50 - Loss: 0.6708 - Accuracy: 0.6204
# Epoch 43/50 - Loss: 0.6705 - Accuracy: 0.6204
# Epoch 44/50 - Loss: 0.6703 - Accuracy: 0.6204
# Epoch 45/50 - Loss: 0.6701 - Accuracy: 0.6204
# Epoch 46/50 - Loss: 0.6699 - Accuracy: 0.6204
# Epoch 47/50 - Loss: 0.6697 - Accuracy: 0.6204
# Epoch 48/50 - Loss: 0.6695 - Accuracy: 0.6204
# Epoch 49/50 - Loss: 0.6693 - Accuracy: 0.6204
# Epoch 50/50 - Loss: 0.6691 - Accuracy: 0.6204
# Testing network size [64, 32] with learning rate 0.001
# Epoch 1/50 - Loss: 0.6921 - Accuracy: 0.6204
# Epoch 2/50 - Loss: 0.6902 - Accuracy: 0.6204
# Epoch 3/50 - Loss: 0.6884 - Accuracy: 0.6204
# Epoch 4/50 - Loss: 0.6868 - Accuracy: 0.6204
# Epoch 5/50 - Loss: 0.6852 - Accuracy: 0.6204
# Epoch 6/50 - Loss: 0.6838 - Accuracy: 0.6204
# Epoch 7/50 - Loss: 0.6824 - Accuracy: 0.6204
# Epoch 8/50 - Loss: 0.6811 - Accuracy: 0.6204
# Epoch 9/50 - Loss: 0.6800 - Accuracy: 0.6204
# Epoch 10/50 - Loss: 0.6789 - Accuracy: 0.6204
# Epoch 11/50 - Loss: 0.6779 - Accuracy: 0.6204
# Epoch 12/50 - Loss: 0.6770 - Accuracy: 0.6204
# Epoch 13/50 - Loss: 0.6761 - Accuracy: 0.6204
# Epoch 14/50 - Loss: 0.6752 - Accuracy: 0.6204
# Epoch 15/50 - Loss: 0.6744 - Accuracy: 0.6204
# Epoch 16/50 - Loss: 0.6737 - Accuracy: 0.6204
# Epoch 17/50 - Loss: 0.6731 - Accuracy: 0.6204
# Epoch 18/50 - Loss: 0.6725 - Accuracy: 0.6204
# Epoch 19/50 - Loss: 0.6719 - Accuracy: 0.6204
# Epoch 20/50 - Loss: 0.6714 - Accuracy: 0.6204
# Epoch 21/50 - Loss: 0.6709 - Accuracy: 0.6204
# Epoch 22/50 - Loss: 0.6704 - Accuracy: 0.6204
# Epoch 23/50 - Loss: 0.6699 - Accuracy: 0.6204
# Epoch 24/50 - Loss: 0.6695 - Accuracy: 0.6204
# Epoch 25/50 - Loss: 0.6691 - Accuracy: 0.6204
# Epoch 26/50 - Loss: 0.6688 - Accuracy: 0.6204
# Epoch 27/50 - Loss: 0.6685 - Accuracy: 0.6204
# Epoch 28/50 - Loss: 0.6682 - Accuracy: 0.6204
# Epoch 29/50 - Loss: 0.6679 - Accuracy: 0.6204
# Epoch 30/50 - Loss: 0.6677 - Accuracy: 0.6204
# Epoch 31/50 - Loss: 0.6674 - Accuracy: 0.6204
# Epoch 32/50 - Loss: 0.6672 - Accuracy: 0.6204
# Epoch 33/50 - Loss: 0.6670 - Accuracy: 0.6204
# Epoch 34/50 - Loss: 0.6667 - Accuracy: 0.6204
# Epoch 35/50 - Loss: 0.6666 - Accuracy: 0.6204
# Epoch 36/50 - Loss: 0.6664 - Accuracy: 0.6204
# Epoch 37/50 - Loss: 0.6662 - Accuracy: 0.6204
# Epoch 38/50 - Loss: 0.6661 - Accuracy: 0.6204
# Epoch 39/50 - Loss: 0.6659 - Accuracy: 0.6204
# Epoch 40/50 - Loss: 0.6658 - Accuracy: 0.6204
# Epoch 41/50 - Loss: 0.6656 - Accuracy: 0.6204
# Epoch 42/50 - Loss: 0.6655 - Accuracy: 0.6204
# Epoch 43/50 - Loss: 0.6654 - Accuracy: 0.6204
# Epoch 44/50 - Loss: 0.6653 - Accuracy: 0.6204
# Epoch 45/50 - Loss: 0.6652 - Accuracy: 0.6204
# Epoch 46/50 - Loss: 0.6651 - Accuracy: 0.6204
# Epoch 47/50 - Loss: 0.6650 - Accuracy: 0.6204
# Epoch 48/50 - Loss: 0.6650 - Accuracy: 0.6204
# Epoch 49/50 - Loss: 0.6649 - Accuracy: 0.6204
# Epoch 50/50 - Loss: 0.6648 - Accuracy: 0.6204
# Testing network size [64, 32] with learning rate 0.001
# Epoch 1/50 - Loss: 0.6927 - Accuracy: 0.6204
# Epoch 2/50 - Loss: 0.6917 - Accuracy: 0.6204
# Epoch 3/50 - Loss: 0.6907 - Accuracy: 0.6204
# Epoch 4/50 - Loss: 0.6898 - Accuracy: 0.6204
# Epoch 5/50 - Loss: 0.6889 - Accuracy: 0.6204
# Epoch 6/50 - Loss: 0.6880 - Accuracy: 0.6204
# Epoch 7/50 - Loss: 0.6872 - Accuracy: 0.6204
# Epoch 8/50 - Loss: 0.6864 - Accuracy: 0.6204
# Epoch 9/50 - Loss: 0.6856 - Accuracy: 0.6204
# Epoch 10/50 - Loss: 0.6849 - Accuracy: 0.6204
# Epoch 11/50 - Loss: 0.6841 - Accuracy: 0.6204
# Epoch 12/50 - Loss: 0.6834 - Accuracy: 0.6204
# Epoch 13/50 - Loss: 0.6828 - Accuracy: 0.6204
# Epoch 14/50 - Loss: 0.6821 - Accuracy: 0.6204
# Epoch 15/50 - Loss: 0.6815 - Accuracy: 0.6204
# Epoch 16/50 - Loss: 0.6809 - Accuracy: 0.6204
# Epoch 17/50 - Loss: 0.6803 - Accuracy: 0.6204
# Epoch 18/50 - Loss: 0.6797 - Accuracy: 0.6204
# Epoch 19/50 - Loss: 0.6792 - Accuracy: 0.6204
# Epoch 20/50 - Loss: 0.6787 - Accuracy: 0.6204
# Epoch 21/50 - Loss: 0.6782 - Accuracy: 0.6204
# Epoch 22/50 - Loss: 0.6777 - Accuracy: 0.6204
# Epoch 23/50 - Loss: 0.6772 - Accuracy: 0.6204
# Epoch 24/50 - Loss: 0.6767 - Accuracy: 0.6204
# Epoch 25/50 - Loss: 0.6763 - Accuracy: 0.6204
# Epoch 26/50 - Loss: 0.6759 - Accuracy: 0.6204
# Epoch 27/50 - Loss: 0.6755 - Accuracy: 0.6204
# Epoch 28/50 - Loss: 0.6751 - Accuracy: 0.6204
# Epoch 29/50 - Loss: 0.6747 - Accuracy: 0.6204
# Epoch 30/50 - Loss: 0.6743 - Accuracy: 0.6204
# Epoch 31/50 - Loss: 0.6740 - Accuracy: 0.6204
# Epoch 32/50 - Loss: 0.6736 - Accuracy: 0.6204
# Epoch 33/50 - Loss: 0.6733 - Accuracy: 0.6204
# Epoch 34/50 - Loss: 0.6730 - Accuracy: 0.6204
# Epoch 35/50 - Loss: 0.6727 - Accuracy: 0.6204
# Epoch 36/50 - Loss: 0.6724 - Accuracy: 0.6204
# Epoch 37/50 - Loss: 0.6721 - Accuracy: 0.6204
# Epoch 38/50 - Loss: 0.6718 - Accuracy: 0.6204
# Epoch 39/50 - Loss: 0.6715 - Accuracy: 0.6204
# Epoch 40/50 - Loss: 0.6713 - Accuracy: 0.6204
# Epoch 41/50 - Loss: 0.6710 - Accuracy: 0.6204
# Epoch 42/50 - Loss: 0.6708 - Accuracy: 0.6204
# Epoch 43/50 - Loss: 0.6705 - Accuracy: 0.6204
# Epoch 44/50 - Loss: 0.6703 - Accuracy: 0.6204
# Epoch 45/50 - Loss: 0.6701 - Accuracy: 0.6204
# Epoch 46/50 - Loss: 0.6699 - Accuracy: 0.6204
# Epoch 47/50 - Loss: 0.6697 - Accuracy: 0.6204
# Epoch 48/50 - Loss: 0.6695 - Accuracy: 0.6204
# Epoch 49/50 - Loss: 0.6693 - Accuracy: 0.6204
# Epoch 50/50 - Loss: 0.6691 - Accuracy: 0.6204
# Testing network size [32, 16] with learning rate 0.0001
# Epoch 1/50 - Loss: 0.6930 - Accuracy: 0.6204
# Epoch 2/50 - Loss: 0.6928 - Accuracy: 0.6204
# Epoch 3/50 - Loss: 0.6926 - Accuracy: 0.6204
# Epoch 4/50 - Loss: 0.6924 - Accuracy: 0.6204
# Epoch 5/50 - Loss: 0.6922 - Accuracy: 0.6204
# Epoch 6/50 - Loss: 0.6920 - Accuracy: 0.6204
# Epoch 7/50 - Loss: 0.6918 - Accuracy: 0.6204
# Epoch 8/50 - Loss: 0.6916 - Accuracy: 0.6204
# Epoch 9/50 - Loss: 0.6914 - Accuracy: 0.6204
# Epoch 10/50 - Loss: 0.6912 - Accuracy: 0.6204
# Epoch 11/50 - Loss: 0.6910 - Accuracy: 0.6204
# Epoch 12/50 - Loss: 0.6908 - Accuracy: 0.6204
# Epoch 13/50 - Loss: 0.6907 - Accuracy: 0.6204
# Epoch 14/50 - Loss: 0.6905 - Accuracy: 0.6204
# Epoch 15/50 - Loss: 0.6903 - Accuracy: 0.6204
# Epoch 16/50 - Loss: 0.6901 - Accuracy: 0.6204
# Epoch 17/50 - Loss: 0.6899 - Accuracy: 0.6204
# Epoch 18/50 - Loss: 0.6897 - Accuracy: 0.6204
# Epoch 19/50 - Loss: 0.6895 - Accuracy: 0.6204
# Epoch 20/50 - Loss: 0.6894 - Accuracy: 0.6204
# Epoch 21/50 - Loss: 0.6892 - Accuracy: 0.6204
# Epoch 22/50 - Loss: 0.6890 - Accuracy: 0.6204
# Epoch 23/50 - Loss: 0.6888 - Accuracy: 0.6204
# Epoch 24/50 - Loss: 0.6887 - Accuracy: 0.6204
# Epoch 25/50 - Loss: 0.6885 - Accuracy: 0.6204
# Epoch 26/50 - Loss: 0.6883 - Accuracy: 0.6204
# Epoch 27/50 - Loss: 0.6881 - Accuracy: 0.6204
# Epoch 28/50 - Loss: 0.6880 - Accuracy: 0.6204
# Epoch 29/50 - Loss: 0.6878 - Accuracy: 0.6204
# Epoch 30/50 - Loss: 0.6877 - Accuracy: 0.6204
# Epoch 31/50 - Loss: 0.6875 - Accuracy: 0.6204
# Epoch 32/50 - Loss: 0.6873 - Accuracy: 0.6204
# Epoch 33/50 - Loss: 0.6872 - Accuracy: 0.6204
# Epoch 34/50 - Loss: 0.6870 - Accuracy: 0.6204
# Epoch 35/50 - Loss: 0.6869 - Accuracy: 0.6204
# Epoch 36/50 - Loss: 0.6867 - Accuracy: 0.6204
# Epoch 37/50 - Loss: 0.6865 - Accuracy: 0.6204
# Epoch 38/50 - Loss: 0.6864 - Accuracy: 0.6204
# Epoch 39/50 - Loss: 0.6862 - Accuracy: 0.6204
# Epoch 40/50 - Loss: 0.6861 - Accuracy: 0.6204
# Epoch 41/50 - Loss: 0.6859 - Accuracy: 0.6204
# Epoch 42/50 - Loss: 0.6857 - Accuracy: 0.6204
# Epoch 43/50 - Loss: 0.6856 - Accuracy: 0.6204
# Epoch 44/50 - Loss: 0.6854 - Accuracy: 0.6204
# Epoch 45/50 - Loss: 0.6853 - Accuracy: 0.6204
# Epoch 46/50 - Loss: 0.6851 - Accuracy: 0.6204
# Epoch 47/50 - Loss: 0.6850 - Accuracy: 0.6204
# Epoch 48/50 - Loss: 0.6848 - Accuracy: 0.6204
# Epoch 49/50 - Loss: 0.6847 - Accuracy: 0.6204
# Epoch 50/50 - Loss: 0.6846 - Accuracy: 0.6204
# Testing network size [32, 16] with learning rate 0.0001
# Epoch 1/50 - Loss: 0.6931 - Accuracy: 0.6204
# Epoch 2/50 - Loss: 0.6930 - Accuracy: 0.6204
# Epoch 3/50 - Loss: 0.6929 - Accuracy: 0.6204
# Epoch 4/50 - Loss: 0.6928 - Accuracy: 0.6204
# Epoch 5/50 - Loss: 0.6927 - Accuracy: 0.6204
# Epoch 6/50 - Loss: 0.6926 - Accuracy: 0.6204
# Epoch 7/50 - Loss: 0.6925 - Accuracy: 0.6204
# Epoch 8/50 - Loss: 0.6924 - Accuracy: 0.6204
# Epoch 9/50 - Loss: 0.6923 - Accuracy: 0.6204
# Epoch 10/50 - Loss: 0.6922 - Accuracy: 0.6204
# Epoch 11/50 - Loss: 0.6921 - Accuracy: 0.6204
# Epoch 12/50 - Loss: 0.6920 - Accuracy: 0.6204
# Epoch 13/50 - Loss: 0.6919 - Accuracy: 0.6204
# Epoch 14/50 - Loss: 0.6918 - Accuracy: 0.6204
# Epoch 15/50 - Loss: 0.6917 - Accuracy: 0.6204
# Epoch 16/50 - Loss: 0.6916 - Accuracy: 0.6204
# Epoch 17/50 - Loss: 0.6915 - Accuracy: 0.6204
# Epoch 18/50 - Loss: 0.6914 - Accuracy: 0.6204
# Epoch 19/50 - Loss: 0.6913 - Accuracy: 0.6204
# Epoch 20/50 - Loss: 0.6912 - Accuracy: 0.6204
# Epoch 21/50 - Loss: 0.6911 - Accuracy: 0.6204
# Epoch 22/50 - Loss: 0.6910 - Accuracy: 0.6204
# Epoch 23/50 - Loss: 0.6909 - Accuracy: 0.6204
# Epoch 24/50 - Loss: 0.6908 - Accuracy: 0.6204
# Epoch 25/50 - Loss: 0.6907 - Accuracy: 0.6204
# Epoch 26/50 - Loss: 0.6906 - Accuracy: 0.6204
# Epoch 27/50 - Loss: 0.6905 - Accuracy: 0.6204
# Epoch 28/50 - Loss: 0.6904 - Accuracy: 0.6204
# Epoch 29/50 - Loss: 0.6904 - Accuracy: 0.6204
# Epoch 30/50 - Loss: 0.6903 - Accuracy: 0.6204
# Epoch 31/50 - Loss: 0.6902 - Accuracy: 0.6204
# Epoch 32/50 - Loss: 0.6901 - Accuracy: 0.6204
# Epoch 33/50 - Loss: 0.6900 - Accuracy: 0.6204
# Epoch 34/50 - Loss: 0.6899 - Accuracy: 0.6204
# Epoch 35/50 - Loss: 0.6898 - Accuracy: 0.6204
# Epoch 36/50 - Loss: 0.6897 - Accuracy: 0.6204
# Epoch 37/50 - Loss: 0.6896 - Accuracy: 0.6204
# Epoch 38/50 - Loss: 0.6895 - Accuracy: 0.6204
# Epoch 39/50 - Loss: 0.6894 - Accuracy: 0.6204
# Epoch 40/50 - Loss: 0.6893 - Accuracy: 0.6204
# Epoch 41/50 - Loss: 0.6893 - Accuracy: 0.6204
# Epoch 42/50 - Loss: 0.6892 - Accuracy: 0.6204
# Epoch 43/50 - Loss: 0.6891 - Accuracy: 0.6204
# Epoch 44/50 - Loss: 0.6890 - Accuracy: 0.6204
# Epoch 45/50 - Loss: 0.6889 - Accuracy: 0.6204
# Epoch 46/50 - Loss: 0.6888 - Accuracy: 0.6204
# Epoch 47/50 - Loss: 0.6887 - Accuracy: 0.6204
# Epoch 48/50 - Loss: 0.6886 - Accuracy: 0.6204
# Epoch 49/50 - Loss: 0.6886 - Accuracy: 0.6204
# Epoch 50/50 - Loss: 0.6885 - Accuracy: 0.6204
# Testing network size [64, 32] with learning rate 0.0001
# Epoch 1/50 - Loss: 0.6930 - Accuracy: 0.6204
# Epoch 2/50 - Loss: 0.6928 - Accuracy: 0.6204
# Epoch 3/50 - Loss: 0.6926 - Accuracy: 0.6204
# Epoch 4/50 - Loss: 0.6924 - Accuracy: 0.6204
# Epoch 5/50 - Loss: 0.6922 - Accuracy: 0.6204
# Epoch 6/50 - Loss: 0.6920 - Accuracy: 0.6204
# Epoch 7/50 - Loss: 0.6918 - Accuracy: 0.6204
# Epoch 8/50 - Loss: 0.6917 - Accuracy: 0.6204
# Epoch 9/50 - Loss: 0.6915 - Accuracy: 0.6204
# Epoch 10/50 - Loss: 0.6913 - Accuracy: 0.6204
# Epoch 11/50 - Loss: 0.6911 - Accuracy: 0.6204
# Epoch 12/50 - Loss: 0.6909 - Accuracy: 0.6204
# Epoch 13/50 - Loss: 0.6907 - Accuracy: 0.6204
# Epoch 14/50 - Loss: 0.6905 - Accuracy: 0.6204
# Epoch 15/50 - Loss: 0.6903 - Accuracy: 0.6204
# Epoch 16/50 - Loss: 0.6901 - Accuracy: 0.6204
# Epoch 17/50 - Loss: 0.6900 - Accuracy: 0.6204
# Epoch 18/50 - Loss: 0.6898 - Accuracy: 0.6204
# Epoch 19/50 - Loss: 0.6896 - Accuracy: 0.6204
# Epoch 20/50 - Loss: 0.6894 - Accuracy: 0.6204
# Epoch 21/50 - Loss: 0.6892 - Accuracy: 0.6204
# Epoch 22/50 - Loss: 0.6891 - Accuracy: 0.6204
# Epoch 23/50 - Loss: 0.6889 - Accuracy: 0.6204
# Epoch 24/50 - Loss: 0.6887 - Accuracy: 0.6204
# Epoch 25/50 - Loss: 0.6885 - Accuracy: 0.6204
# Epoch 26/50 - Loss: 0.6884 - Accuracy: 0.6204
# Epoch 27/50 - Loss: 0.6882 - Accuracy: 0.6204
# Epoch 28/50 - Loss: 0.6880 - Accuracy: 0.6204
# Epoch 29/50 - Loss: 0.6878 - Accuracy: 0.6204
# Epoch 30/50 - Loss: 0.6877 - Accuracy: 0.6204
# Epoch 31/50 - Loss: 0.6875 - Accuracy: 0.6204
# Epoch 32/50 - Loss: 0.6874 - Accuracy: 0.6204
# Epoch 33/50 - Loss: 0.6872 - Accuracy: 0.6204
# Epoch 34/50 - Loss: 0.6870 - Accuracy: 0.6204
# Epoch 35/50 - Loss: 0.6869 - Accuracy: 0.6204
# Epoch 36/50 - Loss: 0.6867 - Accuracy: 0.6204
# Epoch 37/50 - Loss: 0.6865 - Accuracy: 0.6204
# Epoch 38/50 - Loss: 0.6864 - Accuracy: 0.6204
# Epoch 39/50 - Loss: 0.6862 - Accuracy: 0.6204
# Epoch 40/50 - Loss: 0.6861 - Accuracy: 0.6204
# Epoch 41/50 - Loss: 0.6859 - Accuracy: 0.6204
# Epoch 42/50 - Loss: 0.6858 - Accuracy: 0.6204
# Epoch 43/50 - Loss: 0.6856 - Accuracy: 0.6204
# Epoch 44/50 - Loss: 0.6854 - Accuracy: 0.6204
# Epoch 45/50 - Loss: 0.6853 - Accuracy: 0.6204
# Epoch 46/50 - Loss: 0.6851 - Accuracy: 0.6204
# Epoch 47/50 - Loss: 0.6850 - Accuracy: 0.6204
# Epoch 48/50 - Loss: 0.6849 - Accuracy: 0.6204
# Epoch 49/50 - Loss: 0.6847 - Accuracy: 0.6204
# Epoch 50/50 - Loss: 0.6846 - Accuracy: 0.6204
# Testing network size [64, 32] with learning rate 0.0001
# Epoch 1/50 - Loss: 0.6931 - Accuracy: 0.6204
# Epoch 2/50 - Loss: 0.6930 - Accuracy: 0.6204
# Epoch 3/50 - Loss: 0.6929 - Accuracy: 0.6204
# Epoch 4/50 - Loss: 0.6928 - Accuracy: 0.6204
# Epoch 5/50 - Loss: 0.6927 - Accuracy: 0.6204
# Epoch 6/50 - Loss: 0.6926 - Accuracy: 0.6204
# Epoch 7/50 - Loss: 0.6925 - Accuracy: 0.6204
# Epoch 8/50 - Loss: 0.6924 - Accuracy: 0.6204
# Epoch 9/50 - Loss: 0.6923 - Accuracy: 0.6204
# Epoch 10/50 - Loss: 0.6922 - Accuracy: 0.6204
# Epoch 11/50 - Loss: 0.6921 - Accuracy: 0.6204
# Epoch 12/50 - Loss: 0.6920 - Accuracy: 0.6204
# Epoch 13/50 - Loss: 0.6919 - Accuracy: 0.6204
# Epoch 14/50 - Loss: 0.6918 - Accuracy: 0.6204
# Epoch 15/50 - Loss: 0.6917 - Accuracy: 0.6204
# Epoch 16/50 - Loss: 0.6916 - Accuracy: 0.6204
# Epoch 17/50 - Loss: 0.6915 - Accuracy: 0.6204
# Epoch 18/50 - Loss: 0.6914 - Accuracy: 0.6204
# Epoch 19/50 - Loss: 0.6913 - Accuracy: 0.6204
# Epoch 20/50 - Loss: 0.6912 - Accuracy: 0.6204
# Epoch 21/50 - Loss: 0.6911 - Accuracy: 0.6204
# Epoch 22/50 - Loss: 0.6910 - Accuracy: 0.6204
# Epoch 23/50 - Loss: 0.6909 - Accuracy: 0.6204
# Epoch 24/50 - Loss: 0.6908 - Accuracy: 0.6204
# Epoch 25/50 - Loss: 0.6907 - Accuracy: 0.6204
# Epoch 26/50 - Loss: 0.6906 - Accuracy: 0.6204
# Epoch 27/50 - Loss: 0.6905 - Accuracy: 0.6204
# Epoch 28/50 - Loss: 0.6904 - Accuracy: 0.6204
# Epoch 29/50 - Loss: 0.6904 - Accuracy: 0.6204
# Epoch 30/50 - Loss: 0.6903 - Accuracy: 0.6204
# Epoch 31/50 - Loss: 0.6902 - Accuracy: 0.6204
# Epoch 32/50 - Loss: 0.6901 - Accuracy: 0.6204
# Epoch 33/50 - Loss: 0.6900 - Accuracy: 0.6204
# Epoch 34/50 - Loss: 0.6899 - Accuracy: 0.6204
# Epoch 35/50 - Loss: 0.6898 - Accuracy: 0.6204
# Epoch 36/50 - Loss: 0.6897 - Accuracy: 0.6204
# Epoch 37/50 - Loss: 0.6896 - Accuracy: 0.6204
# Epoch 38/50 - Loss: 0.6895 - Accuracy: 0.6204
# Epoch 39/50 - Loss: 0.6894 - Accuracy: 0.6204
# Epoch 40/50 - Loss: 0.6893 - Accuracy: 0.6204
# Epoch 41/50 - Loss: 0.6893 - Accuracy: 0.6204
# Epoch 42/50 - Loss: 0.6892 - Accuracy: 0.6204
# Epoch 43/50 - Loss: 0.6891 - Accuracy: 0.6204
# Epoch 44/50 - Loss: 0.6890 - Accuracy: 0.6204
# Epoch 45/50 - Loss: 0.6889 - Accuracy: 0.6204
# Epoch 46/50 - Loss: 0.6888 - Accuracy: 0.6204
# Epoch 47/50 - Loss: 0.6887 - Accuracy: 0.6204
# Epoch 48/50 - Loss: 0.6886 - Accuracy: 0.6204
# Epoch 49/50 - Loss: 0.6886 - Accuracy: 0.6204
# Epoch 50/50 - Loss: 0.6885 - Accuracy: 0.6204
# Best model found with size [64, 32] and learning rate 0.001

# %% [markdown]
# ### 10) Dataset 3: Adult
#
# Adult dataset: https://archive.ics.uci.edu/dataset/2/adult
#
# **IMPORTANT NOTE:** This dataset is much larger than the previous two (48843 instances). If your code runs slow on your own computer, you may exclude parts of this dataset, but you must keep a minimum of 10000 datapoints.

# %%
dataset_3 = pd.read_csv("adult.csv") # TODO: Read the data.

dataset_3.replace("?", np.nan, inplace=True)
dataset_3.dropna(inplace=True)

categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 
                       'relationship', 'race', 'gender', 'native-country']
dataset_3 = pd.get_dummies(dataset_3, columns=categorical_columns, drop_first=True)

dataset_3["income"] = dataset_3["income"].apply(lambda x: 1 if x.strip() == ">50K" else 0)
dataset_3 = dataset_3.astype('float64')

X = dataset_3.drop("income", axis=1).values
y = dataset_3["income"].values.reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
scaler = preprocessing.StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

nn = NeuralNet(input_dim=X_train_scaled.shape[1],
                     output_dim=1,
                     neurons=[50],
                     activation_functions=["relu", "sigmoid"],
                     loss_function=BCE_loss,
                     d_loss_function=d_BCE_loss)

epochs = 50
learning_rate = 1e-3
batch_size = 64

train_loss_history = []
test_accuracy_history = []

history, accuracy = nn.train_net(X_train_scaled, y_train, batch_size=batch_size, epochs=epochs, 
                                    learning_rate=learning_rate, accuracy_function=binary_accuracy)

print(history)
print(accuracy)
# TODO: Visualize the loss for each epoch
plt.figure(figsize=(12, 6))
plt.plot(history, label="Loss", color='blue')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss per Epoch")
plt.legend()
plt.grid(True)
plt.show()

# TODO: Visulaize the test accuracy for each epoch
plt.figure(figsize=(12, 6))
plt.plot(accuracy, label="Accuracy", color='green')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training Accuracy per Epoch")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50 - Loss: 0.6756 - Accuracy: 0.7520
# Epoch 2/50 - Loss: 0.6466 - Accuracy: 0.7520
# Epoch 3/50 - Loss: 0.6245 - Accuracy: 0.7520
# Epoch 4/50 - Loss: 0.6072 - Accuracy: 0.7520
# Epoch 5/50 - Loss: 0.5934 - Accuracy: 0.7520
# Epoch 6/50 - Loss: 0.5818 - Accuracy: 0.7520
# Epoch 7/50 - Loss: 0.5718 - Accuracy: 0.7520
# Epoch 8/50 - Loss: 0.5625 - Accuracy: 0.7520
# Epoch 9/50 - Loss: 0.5537 - Accuracy: 0.7520
# Epoch 10/50 - Loss: 0.5450 - Accuracy: 0.7520
# Epoch 11/50 - Loss: 0.5362 - Accuracy: 0.7520
# Epoch 12/50 - Loss: 0.5273 - Accuracy: 0.7520
# Epoch 13/50 - Loss: 0.5183 - Accuracy: 0.7520
# Epoch 14/50 - Loss: 0.5094 - Accuracy: 0.7520
# Epoch 15/50 - Loss: 0.5006 - Accuracy: 0.7520
# Epoch 16/50 - Loss: 0.4920 - Accuracy: 0.7520
# Epoch 17/50 - Loss: 0.4838 - Accuracy: 0.7520
# Epoch 18/50 - Loss: 0.4760 - Accuracy: 0.7520
# Epoch 19/50 - Loss: 0.4686 - Accuracy: 0.7520
# Epoch 20/50 - Loss: 0.4615 - Accuracy: 0.7520
# Epoch 21/50 - Loss: 0.4547 - Accuracy: 0.7520
# Epoch 22/50 - Loss: 0.4480 - Accuracy: 0.7520
# Epoch 23/50 - Loss: 0.4415 - Accuracy: 0.7520
# Epoch 24/50 - Loss: 0.4351 - Accuracy: 0.7520
# Epoch 25/50 - Loss: 0.4286 - Accuracy: 0.7520
# Epoch 26/50 - Loss: 0.4221 - Accuracy: 0.7524
# Epoch 27/50 - Loss: 0.4155 - Accuracy: 0.7544
# Epoch 28/50 - Loss: 0.4088 - Accuracy: 0.7566
# Epoch 29/50 - Loss: 0.4022 - Accuracy: 0.7623
# Epoch 30/50 - Loss: 0.3957 - Accuracy: 0.7756
# Epoch 31/50 - Loss: 0.3894 - Accuracy: 0.7925
# Epoch 32/50 - Loss: 0.3835 - Accuracy: 0.8100
# Epoch 33/50 - Loss: 0.3780 - Accuracy: 0.8212
# Epoch 34/50 - Loss: 0.3732 - Accuracy: 0.8272
# Epoch 35/50 - Loss: 0.3688 - Accuracy: 0.8314
# Epoch 36/50 - Loss: 0.3650 - Accuracy: 0.8343
# Epoch 37/50 - Loss: 0.3617 - Accuracy: 0.8348
# Epoch 38/50 - Loss: 0.3588 - Accuracy: 0.8362
# Epoch 39/50 - Loss: 0.3562 - Accuracy: 0.8361
# Epoch 40/50 - Loss: 0.3540 - Accuracy: 0.8368
# Epoch 41/50 - Loss: 0.3521 - Accuracy: 0.8372
# Epoch 42/50 - Loss: 0.3503 - Accuracy: 0.8368
# Epoch 43/50 - Loss: 0.3488 - Accuracy: 0.8371
# Epoch 44/50 - Loss: 0.3474 - Accuracy: 0.8373
# Epoch 45/50 - Loss: 0.3462 - Accuracy: 0.8378
# Epoch 46/50 - Loss: 0.3450 - Accuracy: 0.8381
# Epoch 47/50 - Loss: 0.3440 - Accuracy: 0.8385
# Epoch 48/50 - Loss: 0.3430 - Accuracy: 0.8389
# Epoch 49/50 - Loss: 0.3422 - Accuracy: 0.8392
# Epoch 50/50 - Loss: 0.3414 - Accuracy: 0.8393
# [np.float64(0.6755577522834176), np.float64(0.6465626467889201), np.float64(0.6244584314024163), np.float64(0.6072268615478469), np.float64(0.5933846506485349), np.float64(0.5818347193340352), np.float64(0.5717610539637356), np.float64(0.5625419516120874), np.float64(0.5537212919901389), np.float64(0.5449927509262561), np.float64(0.5362111582512347), np.float64(0.5273008877890342), np.float64(0.5183161085443498), np.float64(0.5093646840985043), np.float64(0.5005714531149774), np.float64(0.49203738455311563), np.float64(0.4838483550346573), np.float64(0.4760290730068935), np.float64(0.46859544748122806), np.float64(0.4614924145378121), np.float64(0.4546644133945346), np.float64(0.448044388072066), np.float64(0.4415472291032479), np.float64(0.43509359650855833), np.float64(0.42862462930612416), np.float64(0.4221024875253506), np.float64(0.41549559777684997), np.float64(0.4088449230047733), np.float64(0.4021934082007934), np.float64(0.3956606924259439), np.float64(0.389387753880028), np.float64(0.3834764979413905), np.float64(0.37804299616389275), np.float64(0.37315127297436373), np.float64(0.36881880099204867), np.float64(0.365000594433988), np.float64(0.3616722689853316), np.float64(0.35877080381478266), np.float64(0.35623906384107257), np.float64(0.3540273326637553), np.float64(0.35207739780416836), np.float64(0.3503459881344111), np.float64(0.3488045654737299), np.float64(0.34742161453576487), np.float64(0.34617011758263516), np.float64(0.34503199208326163), np.float64(0.34399621566069355), np.float64(0.3430474677501631), np.float64(0.34217555227114194), np.float64(0.34136819092418497)]
# [np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7520039803195312), np.float64(0.7524185969373652), np.float64(0.7544087567029687), np.float64(0.7565924042235613), np.float64(0.7622864724418155), np.float64(0.775609486428216), np.float64(0.7924982033279894), np.float64(0.809995024600586), np.float64(0.8212449554978164), np.float64(0.8272430759024821), np.float64(0.8314168831886782), np.float64(0.8343191995135165), np.float64(0.834844380562773), np.float64(0.8361711537398419), np.float64(0.8361158715241307), np.float64(0.8367516170048096), np.float64(0.8372215158383548), np.float64(0.8367516170048096), np.float64(0.837138592514788), np.float64(0.8373044391619217), np.float64(0.8378019791033224), np.float64(0.8380783901818785), np.float64(0.8385482890154238), np.float64(0.8388523412018354), np.float64(0.8392393167118138), np.float64(0.8392669578196694)]

# %% [markdown]
# When hyper-parameter tuning, please write the parameters and network sizes you test here:
#
# * Parameter 1:
# * Parameter 2:
#
# * Neural network sizes:

# %%
# TODO: Hyper-parameter tuning
learning_rates = [1e-4, 1e-5]
batch_size = [32, 64]
network_sizes = [[32, 16], [32, 32]]

best_loss = float('inf')
best_model = None
best_params = None

results = {}

for lr in learning_rates:
    for size in network_sizes:
        for bs in batch_size:
            print(f"Testing network size {size} with learning rate {lr}")
            nn = NeuralNet(input_dim=X_train_scaled.shape[1],
                        output_dim=1,
                        neurons=size,
                        activation_functions=["relu", "relu", "sigmoid"],
                        loss_function=BCE_loss,
                        d_loss_function=d_BCE_loss)

            loss_history, accuracy_history = nn.train_net(X_train_scaled, y_train, batch_size=bs, epochs=50, 
                                                            learning_rate=lr, accuracy_function=binary_accuracy)
            final_loss = loss_history[-1]
            results[(tuple(size), lr, bs)] = (loss_history, accuracy_history)
            if final_loss < best_loss:
                best_loss = final_loss
                best_model = nn
                best_params = (size, lr)

print("Best model found with size", best_params[0], "and learning rate", best_params[1])

# TODO: Visualize the loss after hyper-parameter tuning for each epoch
plt.figure(figsize=(12, 6))
for key, (loss_history, _,) in results.items():
    plt.plot(loss_history, label=f"Size: {key[0]}, LR: {key[1]}, BS: {key[2]}")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss per Epoch (Hyper-parameter Tuning)")
plt.legend()
plt.grid(True)
plt.show()

# TODO: Visulaize the test accuracy after hyper-parameter tuning for each epoch
plt.figure(figsize=(12, 6))
for key, (_, accuracy_history) in results.items():
    plt.plot(accuracy_history, label=f"Size: {key[0]}, LR: {key[1]}, BS: {key[2]}")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Test Accuracy per Epoch (Hyper-parameter Tuning)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Testing network size [32, 16] with learning rate 0.0001
# Epoch 1/50 - Loss: 0.6896 - Accuracy: 0.7520
# Epoch 2/50 - Loss: 0.6828 - Accuracy: 0.7520
# Epoch 3/50 - Loss: 0.6764 - Accuracy: 0.7520
# Epoch 4/50 - Loss: 0.6703 - Accuracy: 0.7520
# Epoch 5/50 - Loss: 0.6646 - Accuracy: 0.7520
# Epoch 6/50 - Loss: 0.6592 - Accuracy: 0.7520
# Epoch 7/50 - Loss: 0.6541 - Accuracy: 0.7520
# Epoch 8/50 - Loss: 0.6492 - Accuracy: 0.7520
# Epoch 9/50 - Loss: 0.6446 - Accuracy: 0.7520
# Epoch 10/50 - Loss: 0.6403 - Accuracy: 0.7520
# Epoch 11/50 - Loss: 0.6362 - Accuracy: 0.7520
# Epoch 12/50 - Loss: 0.6323 - Accuracy: 0.7520
# Epoch 13/50 - Loss: 0.6287 - Accuracy: 0.7520
# Epoch 14/50 - Loss: 0.6252 - Accuracy: 0.7520
# Epoch 15/50 - Loss: 0.6219 - Accuracy: 0.7520
# Epoch 16/50 - Loss: 0.6188 - Accuracy: 0.7520
# Epoch 17/50 - Loss: 0.6159 - Accuracy: 0.7520
# Epoch 18/50 - Loss: 0.6131 - Accuracy: 0.7520
# Epoch 19/50 - Loss: 0.6104 - Accuracy: 0.7520
# Epoch 20/50 - Loss: 0.6079 - Accuracy: 0.7520
# Epoch 21/50 - Loss: 0.6056 - Accuracy: 0.7520
# Epoch 22/50 - Loss: 0.6033 - Accuracy: 0.7520
# Epoch 23/50 - Loss: 0.6012 - Accuracy: 0.7520
# Epoch 24/50 - Loss: 0.5992 - Accuracy: 0.7520
# Epoch 25/50 - Loss: 0.5973 - Accuracy: 0.7520
# Epoch 26/50 - Loss: 0.5955 - Accuracy: 0.7520
# Epoch 27/50 - Loss: 0.5937 - Accuracy: 0.7520
# Epoch 28/50 - Loss: 0.5921 - Accuracy: 0.7520
# Epoch 29/50 - Loss: 0.5906 - Accuracy: 0.7520
# Epoch 30/50 - Loss: 0.5891 - Accuracy: 0.7520
# Epoch 31/50 - Loss: 0.5877 - Accuracy: 0.7520
# Epoch 32/50 - Loss: 0.5864 - Accuracy: 0.7520
# Epoch 33/50 - Loss: 0.5851 - Accuracy: 0.7520
# Epoch 34/50 - Loss: 0.5839 - Accuracy: 0.7520
# Epoch 35/50 - Loss: 0.5828 - Accuracy: 0.7520
# Epoch 36/50 - Loss: 0.5817 - Accuracy: 0.7520
# Epoch 37/50 - Loss: 0.5807 - Accuracy: 0.7520
# Epoch 38/50 - Loss: 0.5797 - Accuracy: 0.7520
# Epoch 39/50 - Loss: 0.5788 - Accuracy: 0.7520
# Epoch 40/50 - Loss: 0.5779 - Accuracy: 0.7520
# Epoch 41/50 - Loss: 0.5771 - Accuracy: 0.7520
# Epoch 42/50 - Loss: 0.5763 - Accuracy: 0.7520
# Epoch 43/50 - Loss: 0.5756 - Accuracy: 0.7520
# Epoch 44/50 - Loss: 0.5748 - Accuracy: 0.7520
# Epoch 45/50 - Loss: 0.5742 - Accuracy: 0.7520
# Epoch 46/50 - Loss: 0.5735 - Accuracy: 0.7520
# Epoch 47/50 - Loss: 0.5729 - Accuracy: 0.7520
# Epoch 48/50 - Loss: 0.5723 - Accuracy: 0.7520
# Epoch 49/50 - Loss: 0.5717 - Accuracy: 0.7520
# Epoch 50/50 - Loss: 0.5712 - Accuracy: 0.7520
# Testing network size [32, 16] with learning rate 0.0001
# Epoch 1/50 - Loss: 0.6914 - Accuracy: 0.7520
# Epoch 2/50 - Loss: 0.6879 - Accuracy: 0.7520
# Epoch 3/50 - Loss: 0.6845 - Accuracy: 0.7520
# Epoch 4/50 - Loss: 0.6812 - Accuracy: 0.7520
# Epoch 5/50 - Loss: 0.6780 - Accuracy: 0.7520
# Epoch 6/50 - Loss: 0.6748 - Accuracy: 0.7520
# Epoch 7/50 - Loss: 0.6718 - Accuracy: 0.7520
# Epoch 8/50 - Loss: 0.6688 - Accuracy: 0.7520
# Epoch 9/50 - Loss: 0.6660 - Accuracy: 0.7520
# Epoch 10/50 - Loss: 0.6632 - Accuracy: 0.7520
# Epoch 11/50 - Loss: 0.6605 - Accuracy: 0.7520
# Epoch 12/50 - Loss: 0.6578 - Accuracy: 0.7520
# Epoch 13/50 - Loss: 0.6553 - Accuracy: 0.7520
# Epoch 14/50 - Loss: 0.6528 - Accuracy: 0.7520
# Epoch 15/50 - Loss: 0.6504 - Accuracy: 0.7520
# Epoch 16/50 - Loss: 0.6480 - Accuracy: 0.7520
# Epoch 17/50 - Loss: 0.6457 - Accuracy: 0.7520
# Epoch 18/50 - Loss: 0.6435 - Accuracy: 0.7520
# Epoch 19/50 - Loss: 0.6413 - Accuracy: 0.7520
# Epoch 20/50 - Loss: 0.6392 - Accuracy: 0.7520
# Epoch 21/50 - Loss: 0.6372 - Accuracy: 0.7520
# Epoch 22/50 - Loss: 0.6352 - Accuracy: 0.7520
# Epoch 23/50 - Loss: 0.6333 - Accuracy: 0.7520
# Epoch 24/50 - Loss: 0.6314 - Accuracy: 0.7520
# Epoch 25/50 - Loss: 0.6295 - Accuracy: 0.7520
# Epoch 26/50 - Loss: 0.6278 - Accuracy: 0.7520
# Epoch 27/50 - Loss: 0.6260 - Accuracy: 0.7520
# Epoch 28/50 - Loss: 0.6243 - Accuracy: 0.7520
# Epoch 29/50 - Loss: 0.6227 - Accuracy: 0.7520
# Epoch 30/50 - Loss: 0.6211 - Accuracy: 0.7520
# Epoch 31/50 - Loss: 0.6195 - Accuracy: 0.7520
# Epoch 32/50 - Loss: 0.6180 - Accuracy: 0.7520
# Epoch 33/50 - Loss: 0.6166 - Accuracy: 0.7520
# Epoch 34/50 - Loss: 0.6151 - Accuracy: 0.7520
# Epoch 35/50 - Loss: 0.6137 - Accuracy: 0.7520
# Epoch 36/50 - Loss: 0.6124 - Accuracy: 0.7520
# Epoch 37/50 - Loss: 0.6111 - Accuracy: 0.7520
# Epoch 38/50 - Loss: 0.6098 - Accuracy: 0.7520
# Epoch 39/50 - Loss: 0.6085 - Accuracy: 0.7520
# Epoch 40/50 - Loss: 0.6073 - Accuracy: 0.7520
# Epoch 41/50 - Loss: 0.6061 - Accuracy: 0.7520
# Epoch 42/50 - Loss: 0.6050 - Accuracy: 0.7520
# Epoch 43/50 - Loss: 0.6039 - Accuracy: 0.7520
# Epoch 44/50 - Loss: 0.6028 - Accuracy: 0.7520
# Epoch 45/50 - Loss: 0.6017 - Accuracy: 0.7520
# Epoch 46/50 - Loss: 0.6007 - Accuracy: 0.7520
# Epoch 47/50 - Loss: 0.5997 - Accuracy: 0.7520
# Epoch 48/50 - Loss: 0.5987 - Accuracy: 0.7520
# Epoch 49/50 - Loss: 0.5977 - Accuracy: 0.7520
# Epoch 50/50 - Loss: 0.5968 - Accuracy: 0.7520
# Testing network size [32, 32] with learning rate 0.0001
# Epoch 1/50 - Loss: 0.6896 - Accuracy: 0.7520
# Epoch 2/50 - Loss: 0.6828 - Accuracy: 0.7520
# Epoch 3/50 - Loss: 0.6764 - Accuracy: 0.7520
# Epoch 4/50 - Loss: 0.6703 - Accuracy: 0.7520
# Epoch 5/50 - Loss: 0.6646 - Accuracy: 0.7520
# Epoch 6/50 - Loss: 0.6592 - Accuracy: 0.7520
# Epoch 7/50 - Loss: 0.6540 - Accuracy: 0.7520
# Epoch 8/50 - Loss: 0.6492 - Accuracy: 0.7520
# Epoch 9/50 - Loss: 0.6446 - Accuracy: 0.7520
# Epoch 10/50 - Loss: 0.6403 - Accuracy: 0.7520
# Epoch 11/50 - Loss: 0.6362 - Accuracy: 0.7520
# Epoch 12/50 - Loss: 0.6323 - Accuracy: 0.7520
# Epoch 13/50 - Loss: 0.6286 - Accuracy: 0.7520
# Epoch 14/50 - Loss: 0.6252 - Accuracy: 0.7520
# Epoch 15/50 - Loss: 0.6219 - Accuracy: 0.7520
# Epoch 16/50 - Loss: 0.6188 - Accuracy: 0.7520
# Epoch 17/50 - Loss: 0.6158 - Accuracy: 0.7520
# Epoch 18/50 - Loss: 0.6130 - Accuracy: 0.7520
# Epoch 19/50 - Loss: 0.6104 - Accuracy: 0.7520
# Epoch 20/50 - Loss: 0.6079 - Accuracy: 0.7520
# Epoch 21/50 - Loss: 0.6055 - Accuracy: 0.7520
# Epoch 22/50 - Loss: 0.6033 - Accuracy: 0.7520
# Epoch 23/50 - Loss: 0.6012 - Accuracy: 0.7520
# Epoch 24/50 - Loss: 0.5992 - Accuracy: 0.7520
# Epoch 25/50 - Loss: 0.5973 - Accuracy: 0.7520
# Epoch 26/50 - Loss: 0.5954 - Accuracy: 0.7520
# Epoch 27/50 - Loss: 0.5937 - Accuracy: 0.7520
# Epoch 28/50 - Loss: 0.5921 - Accuracy: 0.7520
# Epoch 29/50 - Loss: 0.5906 - Accuracy: 0.7520
# Epoch 30/50 - Loss: 0.5891 - Accuracy: 0.7520
# Epoch 31/50 - Loss: 0.5877 - Accuracy: 0.7520
# Epoch 32/50 - Loss: 0.5864 - Accuracy: 0.7520
# Epoch 33/50 - Loss: 0.5851 - Accuracy: 0.7520
# Epoch 34/50 - Loss: 0.5839 - Accuracy: 0.7520
# Epoch 35/50 - Loss: 0.5828 - Accuracy: 0.7520
# Epoch 36/50 - Loss: 0.5817 - Accuracy: 0.7520
# Epoch 37/50 - Loss: 0.5807 - Accuracy: 0.7520
# Epoch 38/50 - Loss: 0.5797 - Accuracy: 0.7520
# Epoch 39/50 - Loss: 0.5788 - Accuracy: 0.7520
# Epoch 40/50 - Loss: 0.5779 - Accuracy: 0.7520
# Epoch 41/50 - Loss: 0.5771 - Accuracy: 0.7520
# Epoch 42/50 - Loss: 0.5763 - Accuracy: 0.7520
# Epoch 43/50 - Loss: 0.5755 - Accuracy: 0.7520
# Epoch 44/50 - Loss: 0.5748 - Accuracy: 0.7520
# Epoch 45/50 - Loss: 0.5741 - Accuracy: 0.7520
# Epoch 46/50 - Loss: 0.5735 - Accuracy: 0.7520
# Epoch 47/50 - Loss: 0.5729 - Accuracy: 0.7520
# Epoch 48/50 - Loss: 0.5723 - Accuracy: 0.7520
# Epoch 49/50 - Loss: 0.5717 - Accuracy: 0.7520
# Epoch 50/50 - Loss: 0.5712 - Accuracy: 0.7520
# Testing network size [32, 32] with learning rate 0.0001
# Epoch 1/50 - Loss: 0.6914 - Accuracy: 0.7520
# Epoch 2/50 - Loss: 0.6879 - Accuracy: 0.7520
# Epoch 3/50 - Loss: 0.6845 - Accuracy: 0.7520
# Epoch 4/50 - Loss: 0.6811 - Accuracy: 0.7520
# Epoch 5/50 - Loss: 0.6779 - Accuracy: 0.7520
# Epoch 6/50 - Loss: 0.6748 - Accuracy: 0.7520
# Epoch 7/50 - Loss: 0.6718 - Accuracy: 0.7520
# Epoch 8/50 - Loss: 0.6688 - Accuracy: 0.7520
# Epoch 9/50 - Loss: 0.6660 - Accuracy: 0.7520
# Epoch 10/50 - Loss: 0.6632 - Accuracy: 0.7520
# Epoch 11/50 - Loss: 0.6604 - Accuracy: 0.7520
# Epoch 12/50 - Loss: 0.6578 - Accuracy: 0.7520
# Epoch 13/50 - Loss: 0.6552 - Accuracy: 0.7520
# Epoch 14/50 - Loss: 0.6528 - Accuracy: 0.7520
# Epoch 15/50 - Loss: 0.6503 - Accuracy: 0.7520
# Epoch 16/50 - Loss: 0.6480 - Accuracy: 0.7520
# Epoch 17/50 - Loss: 0.6457 - Accuracy: 0.7520
# Epoch 18/50 - Loss: 0.6435 - Accuracy: 0.7520
# Epoch 19/50 - Loss: 0.6413 - Accuracy: 0.7520
# Epoch 20/50 - Loss: 0.6392 - Accuracy: 0.7520
# Epoch 21/50 - Loss: 0.6371 - Accuracy: 0.7520
# Epoch 22/50 - Loss: 0.6351 - Accuracy: 0.7520
# Epoch 23/50 - Loss: 0.6332 - Accuracy: 0.7520
# Epoch 24/50 - Loss: 0.6313 - Accuracy: 0.7520
# Epoch 25/50 - Loss: 0.6295 - Accuracy: 0.7520
# Epoch 26/50 - Loss: 0.6277 - Accuracy: 0.7520
# Epoch 27/50 - Loss: 0.6260 - Accuracy: 0.7520
# Epoch 28/50 - Loss: 0.6243 - Accuracy: 0.7520
# Epoch 29/50 - Loss: 0.6226 - Accuracy: 0.7520
# Epoch 30/50 - Loss: 0.6210 - Accuracy: 0.7520
# Epoch 31/50 - Loss: 0.6195 - Accuracy: 0.7520
# Epoch 32/50 - Loss: 0.6180 - Accuracy: 0.7520
# Epoch 33/50 - Loss: 0.6165 - Accuracy: 0.7520
# Epoch 34/50 - Loss: 0.6151 - Accuracy: 0.7520
# Epoch 35/50 - Loss: 0.6137 - Accuracy: 0.7520
# Epoch 36/50 - Loss: 0.6123 - Accuracy: 0.7520
# Epoch 37/50 - Loss: 0.6110 - Accuracy: 0.7520
# Epoch 38/50 - Loss: 0.6097 - Accuracy: 0.7520
# Epoch 39/50 - Loss: 0.6085 - Accuracy: 0.7520
# Epoch 40/50 - Loss: 0.6073 - Accuracy: 0.7520
# Epoch 41/50 - Loss: 0.6061 - Accuracy: 0.7520
# Epoch 42/50 - Loss: 0.6049 - Accuracy: 0.7520
# Epoch 43/50 - Loss: 0.6038 - Accuracy: 0.7520
# Epoch 44/50 - Loss: 0.6027 - Accuracy: 0.7520
# Epoch 45/50 - Loss: 0.6017 - Accuracy: 0.7520
# Epoch 46/50 - Loss: 0.6006 - Accuracy: 0.7520
# Epoch 47/50 - Loss: 0.5996 - Accuracy: 0.7520
# Epoch 48/50 - Loss: 0.5986 - Accuracy: 0.7520
# Epoch 49/50 - Loss: 0.5977 - Accuracy: 0.7520
# Epoch 50/50 - Loss: 0.5968 - Accuracy: 0.7520
# Testing network size [32, 16] with learning rate 1e-05
# Epoch 1/50 - Loss: 0.6928 - Accuracy: 0.7520
# Epoch 2/50 - Loss: 0.6921 - Accuracy: 0.7520
# Epoch 3/50 - Loss: 0.6914 - Accuracy: 0.7520
# Epoch 4/50 - Loss: 0.6907 - Accuracy: 0.7520
# Epoch 5/50 - Loss: 0.6900 - Accuracy: 0.7520
# Epoch 6/50 - Loss: 0.6893 - Accuracy: 0.7520
# Epoch 7/50 - Loss: 0.6886 - Accuracy: 0.7520
# Epoch 8/50 - Loss: 0.6879 - Accuracy: 0.7520
# Epoch 9/50 - Loss: 0.6872 - Accuracy: 0.7520
# Epoch 10/50 - Loss: 0.6865 - Accuracy: 0.7520
# Epoch 11/50 - Loss: 0.6858 - Accuracy: 0.7520
# Epoch 12/50 - Loss: 0.6852 - Accuracy: 0.7520
# Epoch 13/50 - Loss: 0.6845 - Accuracy: 0.7520
# Epoch 14/50 - Loss: 0.6838 - Accuracy: 0.7520
# Epoch 15/50 - Loss: 0.6832 - Accuracy: 0.7520
# Epoch 16/50 - Loss: 0.6825 - Accuracy: 0.7520
# Epoch 17/50 - Loss: 0.6818 - Accuracy: 0.7520
# Epoch 18/50 - Loss: 0.6812 - Accuracy: 0.7520
# Epoch 19/50 - Loss: 0.6805 - Accuracy: 0.7520
# Epoch 20/50 - Loss: 0.6799 - Accuracy: 0.7520
# Epoch 21/50 - Loss: 0.6793 - Accuracy: 0.7520
# Epoch 22/50 - Loss: 0.6786 - Accuracy: 0.7520
# Epoch 23/50 - Loss: 0.6780 - Accuracy: 0.7520
# Epoch 24/50 - Loss: 0.6773 - Accuracy: 0.7520
# Epoch 25/50 - Loss: 0.6767 - Accuracy: 0.7520
# Epoch 26/50 - Loss: 0.6761 - Accuracy: 0.7520
# Epoch 27/50 - Loss: 0.6755 - Accuracy: 0.7520
# Epoch 28/50 - Loss: 0.6749 - Accuracy: 0.7520
# Epoch 29/50 - Loss: 0.6742 - Accuracy: 0.7520
# Epoch 30/50 - Loss: 0.6736 - Accuracy: 0.7520
# Epoch 31/50 - Loss: 0.6730 - Accuracy: 0.7520
# Epoch 32/50 - Loss: 0.6724 - Accuracy: 0.7520
# Epoch 33/50 - Loss: 0.6718 - Accuracy: 0.7520
# Epoch 34/50 - Loss: 0.6712 - Accuracy: 0.7520
# Epoch 35/50 - Loss: 0.6706 - Accuracy: 0.7520
# Epoch 36/50 - Loss: 0.6700 - Accuracy: 0.7520
# Epoch 37/50 - Loss: 0.6695 - Accuracy: 0.7520
# Epoch 38/50 - Loss: 0.6689 - Accuracy: 0.7520
# Epoch 39/50 - Loss: 0.6683 - Accuracy: 0.7520
# Epoch 40/50 - Loss: 0.6677 - Accuracy: 0.7520
# Epoch 41/50 - Loss: 0.6672 - Accuracy: 0.7520
# Epoch 42/50 - Loss: 0.6666 - Accuracy: 0.7520
# Epoch 43/50 - Loss: 0.6660 - Accuracy: 0.7520
# Epoch 44/50 - Loss: 0.6655 - Accuracy: 0.7520
# Epoch 45/50 - Loss: 0.6649 - Accuracy: 0.7520
# Epoch 46/50 - Loss: 0.6643 - Accuracy: 0.7520
# Epoch 47/50 - Loss: 0.6638 - Accuracy: 0.7520
# Epoch 48/50 - Loss: 0.6632 - Accuracy: 0.7520
# Epoch 49/50 - Loss: 0.6627 - Accuracy: 0.7520
# Epoch 50/50 - Loss: 0.6621 - Accuracy: 0.7520
# Testing network size [32, 16] with learning rate 1e-05
# Epoch 1/50 - Loss: 0.6930 - Accuracy: 0.7520
# Epoch 2/50 - Loss: 0.6926 - Accuracy: 0.7520
# Epoch 3/50 - Loss: 0.6923 - Accuracy: 0.7520
# Epoch 4/50 - Loss: 0.6919 - Accuracy: 0.7520
# Epoch 5/50 - Loss: 0.6916 - Accuracy: 0.7520
# Epoch 6/50 - Loss: 0.6912 - Accuracy: 0.7520
# Epoch 7/50 - Loss: 0.6909 - Accuracy: 0.7520
# Epoch 8/50 - Loss: 0.6905 - Accuracy: 0.7520
# Epoch 9/50 - Loss: 0.6902 - Accuracy: 0.7520
# Epoch 10/50 - Loss: 0.6898 - Accuracy: 0.7520
# Epoch 11/50 - Loss: 0.6895 - Accuracy: 0.7520
# Epoch 12/50 - Loss: 0.6891 - Accuracy: 0.7520
# Epoch 13/50 - Loss: 0.6888 - Accuracy: 0.7520
# Epoch 14/50 - Loss: 0.6884 - Accuracy: 0.7520
# Epoch 15/50 - Loss: 0.6881 - Accuracy: 0.7520
# Epoch 16/50 - Loss: 0.6877 - Accuracy: 0.7520
# Epoch 17/50 - Loss: 0.6874 - Accuracy: 0.7520
# Epoch 18/50 - Loss: 0.6870 - Accuracy: 0.7520
# Epoch 19/50 - Loss: 0.6867 - Accuracy: 0.7520
# Epoch 20/50 - Loss: 0.6864 - Accuracy: 0.7520
# Epoch 21/50 - Loss: 0.6860 - Accuracy: 0.7520
# Epoch 22/50 - Loss: 0.6857 - Accuracy: 0.7520
# Epoch 23/50 - Loss: 0.6853 - Accuracy: 0.7520
# Epoch 24/50 - Loss: 0.6850 - Accuracy: 0.7520
# Epoch 25/50 - Loss: 0.6847 - Accuracy: 0.7520
# Epoch 26/50 - Loss: 0.6843 - Accuracy: 0.7520
# Epoch 27/50 - Loss: 0.6840 - Accuracy: 0.7520
# Epoch 28/50 - Loss: 0.6837 - Accuracy: 0.7520
# Epoch 29/50 - Loss: 0.6833 - Accuracy: 0.7520
# Epoch 30/50 - Loss: 0.6830 - Accuracy: 0.7520
# Epoch 31/50 - Loss: 0.6827 - Accuracy: 0.7520
# Epoch 32/50 - Loss: 0.6823 - Accuracy: 0.7520
# Epoch 33/50 - Loss: 0.6820 - Accuracy: 0.7520
# Epoch 34/50 - Loss: 0.6817 - Accuracy: 0.7520
# Epoch 35/50 - Loss: 0.6814 - Accuracy: 0.7520
# Epoch 36/50 - Loss: 0.6810 - Accuracy: 0.7520
# Epoch 37/50 - Loss: 0.6807 - Accuracy: 0.7520
# Epoch 38/50 - Loss: 0.6804 - Accuracy: 0.7520
# Epoch 39/50 - Loss: 0.6801 - Accuracy: 0.7520
# Epoch 40/50 - Loss: 0.6797 - Accuracy: 0.7520
# Epoch 41/50 - Loss: 0.6794 - Accuracy: 0.7520
# Epoch 42/50 - Loss: 0.6791 - Accuracy: 0.7520
# Epoch 43/50 - Loss: 0.6788 - Accuracy: 0.7520
# Epoch 44/50 - Loss: 0.6785 - Accuracy: 0.7520
# Epoch 45/50 - Loss: 0.6781 - Accuracy: 0.7520
# Epoch 46/50 - Loss: 0.6778 - Accuracy: 0.7520
# Epoch 47/50 - Loss: 0.6775 - Accuracy: 0.7520
# Epoch 48/50 - Loss: 0.6772 - Accuracy: 0.7520
# Epoch 49/50 - Loss: 0.6769 - Accuracy: 0.7520
# Epoch 50/50 - Loss: 0.6766 - Accuracy: 0.7520
# Testing network size [32, 32] with learning rate 1e-05
# Epoch 1/50 - Loss: 0.6928 - Accuracy: 0.7520
# Epoch 2/50 - Loss: 0.6921 - Accuracy: 0.7520
# Epoch 3/50 - Loss: 0.6913 - Accuracy: 0.7520
# Epoch 4/50 - Loss: 0.6906 - Accuracy: 0.7520
# Epoch 5/50 - Loss: 0.6899 - Accuracy: 0.7520
# Epoch 6/50 - Loss: 0.6892 - Accuracy: 0.7520
# Epoch 7/50 - Loss: 0.6885 - Accuracy: 0.7520
# Epoch 8/50 - Loss: 0.6879 - Accuracy: 0.7520
# Epoch 9/50 - Loss: 0.6872 - Accuracy: 0.7520
# Epoch 10/50 - Loss: 0.6865 - Accuracy: 0.7520
# Epoch 11/50 - Loss: 0.6858 - Accuracy: 0.7520
# Epoch 12/50 - Loss: 0.6851 - Accuracy: 0.7520
# Epoch 13/50 - Loss: 0.6845 - Accuracy: 0.7520
# Epoch 14/50 - Loss: 0.6838 - Accuracy: 0.7520
# Epoch 15/50 - Loss: 0.6831 - Accuracy: 0.7520
# Epoch 16/50 - Loss: 0.6825 - Accuracy: 0.7520
# Epoch 17/50 - Loss: 0.6818 - Accuracy: 0.7520
# Epoch 18/50 - Loss: 0.6812 - Accuracy: 0.7520
# Epoch 19/50 - Loss: 0.6805 - Accuracy: 0.7520
# Epoch 20/50 - Loss: 0.6799 - Accuracy: 0.7520
# Epoch 21/50 - Loss: 0.6792 - Accuracy: 0.7520
# Epoch 22/50 - Loss: 0.6786 - Accuracy: 0.7520
# Epoch 23/50 - Loss: 0.6779 - Accuracy: 0.7520
# Epoch 24/50 - Loss: 0.6773 - Accuracy: 0.7520
# Epoch 25/50 - Loss: 0.6767 - Accuracy: 0.7520
# Epoch 26/50 - Loss: 0.6761 - Accuracy: 0.7520
# Epoch 27/50 - Loss: 0.6754 - Accuracy: 0.7520
# Epoch 28/50 - Loss: 0.6748 - Accuracy: 0.7520
# Epoch 29/50 - Loss: 0.6742 - Accuracy: 0.7520
# Epoch 30/50 - Loss: 0.6736 - Accuracy: 0.7520
# Epoch 31/50 - Loss: 0.6730 - Accuracy: 0.7520
# Epoch 32/50 - Loss: 0.6724 - Accuracy: 0.7520
# Epoch 33/50 - Loss: 0.6718 - Accuracy: 0.7520
# Epoch 34/50 - Loss: 0.6712 - Accuracy: 0.7520
# Epoch 35/50 - Loss: 0.6706 - Accuracy: 0.7520
# Epoch 36/50 - Loss: 0.6700 - Accuracy: 0.7520
# Epoch 37/50 - Loss: 0.6694 - Accuracy: 0.7520
# Epoch 38/50 - Loss: 0.6688 - Accuracy: 0.7520
# Epoch 39/50 - Loss: 0.6683 - Accuracy: 0.7520
# Epoch 40/50 - Loss: 0.6677 - Accuracy: 0.7520
# Epoch 41/50 - Loss: 0.6671 - Accuracy: 0.7520
# Epoch 42/50 - Loss: 0.6665 - Accuracy: 0.7520
# Epoch 43/50 - Loss: 0.6660 - Accuracy: 0.7520
# Epoch 44/50 - Loss: 0.6654 - Accuracy: 0.7520
# Epoch 45/50 - Loss: 0.6648 - Accuracy: 0.7520
# Epoch 46/50 - Loss: 0.6643 - Accuracy: 0.7520
# Epoch 47/50 - Loss: 0.6637 - Accuracy: 0.7520
# Epoch 48/50 - Loss: 0.6632 - Accuracy: 0.7520
# Epoch 49/50 - Loss: 0.6626 - Accuracy: 0.7520
# Epoch 50/50 - Loss: 0.6621 - Accuracy: 0.7520
# Testing network size [32, 32] with learning rate 1e-05
# Epoch 1/50 - Loss: 0.6930 - Accuracy: 0.7519
# Epoch 2/50 - Loss: 0.6926 - Accuracy: 0.7520
# Epoch 3/50 - Loss: 0.6923 - Accuracy: 0.7520
# Epoch 4/50 - Loss: 0.6919 - Accuracy: 0.7520
# Epoch 5/50 - Loss: 0.6916 - Accuracy: 0.7520
# Epoch 6/50 - Loss: 0.6912 - Accuracy: 0.7520
# Epoch 7/50 - Loss: 0.6908 - Accuracy: 0.7520
# Epoch 8/50 - Loss: 0.6905 - Accuracy: 0.7520
# Epoch 9/50 - Loss: 0.6901 - Accuracy: 0.7520
# Epoch 10/50 - Loss: 0.6898 - Accuracy: 0.7520
# Epoch 11/50 - Loss: 0.6894 - Accuracy: 0.7520
# Epoch 12/50 - Loss: 0.6891 - Accuracy: 0.7520
# Epoch 13/50 - Loss: 0.6887 - Accuracy: 0.7520
# Epoch 14/50 - Loss: 0.6884 - Accuracy: 0.7520
# Epoch 15/50 - Loss: 0.6881 - Accuracy: 0.7520
# Epoch 16/50 - Loss: 0.6877 - Accuracy: 0.7520
# Epoch 17/50 - Loss: 0.6874 - Accuracy: 0.7520
# Epoch 18/50 - Loss: 0.6870 - Accuracy: 0.7520
# Epoch 19/50 - Loss: 0.6867 - Accuracy: 0.7520
# Epoch 20/50 - Loss: 0.6863 - Accuracy: 0.7520
# Epoch 21/50 - Loss: 0.6860 - Accuracy: 0.7520
# Epoch 22/50 - Loss: 0.6857 - Accuracy: 0.7520
# Epoch 23/50 - Loss: 0.6853 - Accuracy: 0.7520
# Epoch 24/50 - Loss: 0.6850 - Accuracy: 0.7520
# Epoch 25/50 - Loss: 0.6846 - Accuracy: 0.7520
# Epoch 26/50 - Loss: 0.6843 - Accuracy: 0.7520
# Epoch 27/50 - Loss: 0.6840 - Accuracy: 0.7520
# Epoch 28/50 - Loss: 0.6836 - Accuracy: 0.7520
# Epoch 29/50 - Loss: 0.6833 - Accuracy: 0.7520
# Epoch 30/50 - Loss: 0.6830 - Accuracy: 0.7520
# Epoch 31/50 - Loss: 0.6827 - Accuracy: 0.7520
# Epoch 32/50 - Loss: 0.6823 - Accuracy: 0.7520
# Epoch 33/50 - Loss: 0.6820 - Accuracy: 0.7520
# Epoch 34/50 - Loss: 0.6817 - Accuracy: 0.7520
# Epoch 35/50 - Loss: 0.6813 - Accuracy: 0.7520
# Epoch 36/50 - Loss: 0.6810 - Accuracy: 0.7520
# Epoch 37/50 - Loss: 0.6807 - Accuracy: 0.7520
# Epoch 38/50 - Loss: 0.6804 - Accuracy: 0.7520
# Epoch 39/50 - Loss: 0.6800 - Accuracy: 0.7520
# Epoch 40/50 - Loss: 0.6797 - Accuracy: 0.7520
# Epoch 41/50 - Loss: 0.6794 - Accuracy: 0.7520
# Epoch 42/50 - Loss: 0.6791 - Accuracy: 0.7520
# Epoch 43/50 - Loss: 0.6788 - Accuracy: 0.7520
# Epoch 44/50 - Loss: 0.6784 - Accuracy: 0.7520
# Epoch 45/50 - Loss: 0.6781 - Accuracy: 0.7520
# Epoch 46/50 - Loss: 0.6778 - Accuracy: 0.7520
# Epoch 47/50 - Loss: 0.6775 - Accuracy: 0.7520
# Epoch 48/50 - Loss: 0.6772 - Accuracy: 0.7520
# Epoch 49/50 - Loss: 0.6769 - Accuracy: 0.7520
# Epoch 50/50 - Loss: 0.6765 - Accuracy: 0.7520
# Best model found with size [32, 32] and learning rate 0.0001

# %% [markdown]
# # Questions for examination:
#
# In addition to completing the assignment with all its tasks, you should also prepare to answer the following questions:
#
# 1) Why would we want to use different activation functions?
#
# 2) Why would we want to use different loss functions?
#
# 3) Why are neural networks sensitive to large input values?
#
# 4) What is the role of the bias?
#
# 5) What is the purpose of hyper-parameter tuning?
#
# 6) A small example neural network will be shown during the oral examination. You will be asked a few basic questions related to the number of weights, biases, inputs and outputs.

# %% [markdown]
# # Finished!
#
# Was part of the setup incorrect? Did you spot any inconsistencies in the assignment? Could something improve?
#
# If so, please write them and send via email and send it to:
#
# * marcus.gullstrand@ju.se
#
# Thank you!
